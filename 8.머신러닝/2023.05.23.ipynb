# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in c:\users\h\anaconda3\lib\site-packages (0.2.7)
# Requirement already satisfied: future in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: numpy in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (1.21.5)
# Requirement already satisfied: tqdm in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (4.64.1)
# Requirement already satisfied: scipy in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (2.8.4)
# Requirement already satisfied: six in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: cloudpickle in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (2.0.0)
# Requirement already satisfied: py4j in c:\users\h\anaconda3\lib\site-packages (from hyperopt) (0.10.9.7)
# Requirement already satisfied: colorama in c:\users\h\anaconda3\lib\site-packages (from tqdm->hyperopt) (0.4.5)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\h\anaconda3\lib\site-packages)

# %% [markdown]
# ### HyperOpt 라이브러리의 주요 함수와 개념
#
# - fmin: 이 함수는 최적화 과정을 수행하는 주요 함수입니다. 이 함수는 목표 함수(fn), 검색 공간(space), 최적화 알고리즘(algo), 그리고 최대 평가 횟수(max_evals) 등을 인자로 받습니다. 이 함수는 최적의 하이퍼파라미터 설정을 찾기 위해 주어진 알고리즘을 사용하여 검색 공간을 탐색하고, 각 설정에 대해 목표 함수를 평가합니다.
#
# - tpe: 이것은 Tree-structured Parzen Estimator(TPE) 알고리즘을 나타내며, HyperOpt에서 사용할 수 있는 최적화 알고리즘 중 하나입니다. TPE는 베이지안 최적화 알고리즘의 한 종류로, 이전의 평가 결과를 기반으로 하여 다음에 테스트할 하이퍼파라미터를 선택합니다. 이렇게 하면 더 좋은 결과를 내는 하이퍼파라미터의 영역을 더 자주 탐색하게 됩니다.
#
# - hp: 이것은 HyperOpt의 검색 공간을 정의하는 데 사용되는 함수들을 담고 있는 모듈입니다. 예를 들어, hp.uniform('x', 0, 1)은 0과 1 사이에서 균일하게 분포한 실수 값을 가지는 'x'라는 하이퍼파라미터를 정의합니다. 다른 함수로는 hp.choice (여러 선택 사항 중 하나를 선택), hp.normal (정규 분포에서 값을 선택) 등이 있습니다.
#
# - STATUS_OK: 이것은 목표 함수가 성공적으로 완료되었음을 나타내는 상태 코드입니다. 목표 함수는 손실값과 상태 코드를 포함하는 딕셔너리를 반환해야 합니다. 이 상태 코드는 HyperOpt가 평가를 제대로 수행했는지 판단하는 데 사용됩니다. 만약 다른 값을 반환하면, HyperOpt는 해당 평가가 실패했다고 판단하고, 해당 설정을 더 이상 탐색하지 않습니다.

# %% [markdown]
# ### Tree-structured Parzen Estimator (TPE)
# - 하이퍼파라미터 최적화를 위한 알고리즘 중 하나입니다. Bayesian optimization의 한 종류로, 하이퍼파라미터의 새로운 조합을 선택하는 방법으로 주로 사용됩니다.
#
# - TPE 알고리즘의 핵심 아이디어는 과거의 평가 결과를 기반으로 하이퍼파라미터의 좋은 값과 나쁜 값에 대한 확률 모델을 구축하고, 이 모델을 사용하여 다음에 시도할 하이퍼파라미터 값을 선택하는 것입니다.
#
# - TPE는 이를 위해 두 개의 확률 분포 l(x)와 g(x)를 사용합니다. 여기서 x는 하이퍼파라미터를 의미하며, l(x)는 과거의 좋은 하이퍼파라미터 값들에 대한 분포를 나타내고, g(x)는 모든 과거의 하이퍼파라미터 값들에 대한 분포를 나타냅니다.
#
# - 이 두 분포를 이용해 새로운 하이퍼파라미터 값 x를 선택할 때, l(x)/g(x)가 큰 값, 즉 과거의 좋은 하이퍼파라미터 값들에 더 가까운 값을 선택합니다.
#
# - 이런 방식으로, TPE는 점점 더 좋은 하이퍼파라미터 값을 찾아가는 탐색 과정을 수행합니다. 이는 전통적인 Grid Search나 Random Search에 비해 효율적이며, 보다 적은 평가로 좋은 하이퍼파라미터 값을 찾을 수 있게 합니다.

# %% [markdown]
# ### make_classification 함수 매개변수
#
# - n_samples: 생성할 샘플의 개수를 지정합니다. 기본값은 100입니다.
# - n_features: 독립 변수의 개수를 지정합니다. 기본값은 20입니다.
# - n_informative: 종속 변수와 관련된 독립 변수의 수를 지정합니다. 기본값은 2입니다.
# - n_redundant: 다른 독립 변수의 선형 조합으로 생성된 독립 변수의 수를 지정합니다. 기본값은 2입니다.
# - n_classes: 생성할 클래스(또는 레이블)의 개수를 지정합니다. 기본값은 2입니다.
#
# 이 함수는 X와 y의 두 개의 배열을 반환합니다. X는 n_samples x n_features 크기의 2차원 배열로, 독립 변수를 포함하고 있습니다. y는 n_samples 크기의 1차원 배열로, 각 샘플의 클래스 레이블을 포함하고 있습니다.

# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_samples = 1000, n_features = 10, n_classes = 2)

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

X, y = make_classification()

def objective(args) :
    # 모델 설정 - c는 규제의 역수로 c 값이 작을수록 규제가 강하며 반대인 경우 규제가 약해집니다
    model = LogisticRegression(C = args['C'])
    # 모델 검증 - 교차검증을 수행하고 평균 정확도 계산
    score = cross_val_score(model, X, y, cv = 5).mean()
    # 손실값 계산 - 손실값을 1 - 정확도로 계산
    loss = 1 - score
    
    return{'loss' : loss, 'status' : STATUS_OK}

# 검색 공간 정의 - 최적화할 하이퍼파라미터 c의 범위를 정의
space = {'C' : hp.loguniform('C', -5, 0)}

#  최적화 실행 - tpe 알고리즘을 사용하여 목표 함수를 최적화하고  최대 100회의 평가를 수행합니다
best = fmin(fn = objective, space = space, algo = tpe.suggest, max_evals = 100)

print(best)
# Out:
# 100%|█████████████████████████████████████████████| 100/100 [00:01<00:00, 50.70trial/s, best loss: 0.16999999999999993]
# {'C': 0.7471525613377162}

# %% [markdown]
# ### Hyperopt 사용법
#
# - 입력 변수명과 입력값의 검색 공간 설정
# - 목적 함수의 설정
# - 목적 함수의 반환 최소값을 가지는 최적 입력값을 유추

# %%
search_space = {'x' : hp.quniform('x', -10, 10, 1), 'y' : hp.quniform('y', -15, 15, 1)}

# %%
def objective_func(search_space) :
    x = search_space['x']
    y = search_space['y']
    
    retval = x ** 2 - 20 * y
    
    return retval

# %%
from hyperopt import Trials
import numpy as np

trial_val = Trials()

best_01 = fmin(fn = objective_func, space = search_space, algo = tpe.suggest, max_evals = 5,
              trials = trial_val, rstate = np.random.default_rng(seed = 0))

print('best : ', best_01, '\n')

best_02 = fmin(fn = objective_func, space = search_space, algo = tpe.suggest, max_evals = 20,
              trials = trial_val, rstate = np.random.default_rng(seed = 0))

print('best : ', best_02)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 833.99trial/s, best loss: -224.0]
# best :  {'x': -4.0, 'y': 12.0}
#
# 100%|███████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 832.43trial/s, best loss: -296.0]
# best :  {'x': 2.0, 'y': 15.0}

# %%
print(trial_val.results)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}]

# %%
print(trial_val.vals)
# Out:
# {'x': [-6.0, -4.0, 4.0, -4.0, 9.0, -6.0, -4.0, 4.0, -4.0, 9.0, 2.0, 10.0, -9.0, -8.0, -0.0, -0.0, 1.0, 9.0, 6.0, 9.0], 'y': [5.0, 10.0, -2.0, 12.0, 1.0, 5.0, 10.0, -2.0, 12.0, 1.0, 15.0, 7.0, -10.0, 0.0, -5.0, -3.0, 2.0, 4.0, 10.0, 3.0]}

# %%
import pandas as pd

losses = [loss_dict['loss'] for loss_dict in trial_val.results]

result_df = pd.DataFrame({'x' : trial_val.vals['x'], 'y' : trial_val.vals['y'], 'losses' : losses})

result_df.head()
# Out:
#      x     y  losses
# 0 -6.0   5.0   -64.0
# 1 -4.0  10.0  -184.0
# 2  4.0  -2.0    56.0
# 3 -4.0  12.0  -224.0
# 4  9.0   1.0    61.0

# %% [markdown]
# ### 과제1 3개의 와인 클래스 분류

# %%
# Scikit-learn을 활용한 나이브 베이즈 분류기 구축 

from sklearn import datasets

#Load dataset
wine = datasets.load_wine()

# print the names of the 13 features
print("Features: ", wine.feature_names)

# print the label type of wine(class_0, class_1, class_2)
print("Labels: ", wine.target_names)
# Out:
# Features:  ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Labels:  ['class_0' 'class_1' 'class_2']

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics

X = wine.data
y = wine.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

gauss = GaussianNB()

gauss.fit(X_train, y_train)
pred = gauss.predict(X_test)

accuracy = accuracy_score(y_test, pred)

print('accuracy : ', accuracy)
print('class report : \n', metrics.classification_report(y_test, pred))
# Out:
# accuracy :  0.8888888888888888
# class report :
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.78      0.88        18
#            2       0.73      1.00      0.84         8
#
#     accuracy                           0.89        36
#    macro avg       0.88      0.93      0.89        36
# weighted avg       0.91      0.89      0.89        36

# %% [markdown]
# ###  과제2  위스콘신 유방암 데이터 세트를 로딩해서 xgbooster 알고리즘으로 모델링 및 평가를 수행하세요 단 hyperopt 를 이용해서 하이퍼 파라미터를 최적화하세요

# %% [markdown]
# sklearn의 load_breast_cancer 함수를 사용하여 위스콘신 유방암 데이터 세트를 로딩합니다. 데이터를 훈련 데이터와 테스트 데이터로 분할한 후, Hyperopt의 fmin 함수를 사용하여 Objective 함수를 최적화합니다. Objective 함수는 XGBoost 모델을 초기화하고 훈련 데이터에 대해 학습한 뒤, 테스트 데이터에 대한 정확도를 계산하여 반환합니다. Hyperopt는 최적화를 위해 값을 최소화하므로, 음수로 정확도를 반환하도록 설정합니다. 최적화된 하이퍼파라미터는 best 변수에 저장되며, 최종 모델은 이를 사용하여 다시 학습하고 평가합니다.
#
# 위 코드를 실행하면 Hyperopt를 사용하여 XGBoost 모델의 하이퍼파라미터를 최적화하고, 최종적으로 테스트 데이터에 대한 정확도를 출력합니다.

# %%
import xgboost as xgb
from xgboost import plot_importance
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from hyperopt import hp, fmin, tpe, Trials
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# 데이터 세트 로드
dataset = load_breast_cancer()

X = dataset.data
y = dataset.target

# 훈련 데이터와 테스트 데이터로 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# 모델링을 위한 함수 정의
def objective(args) :
    
    # 하이퍼파라미터 추출
    learning_rate = args['learning_rate']
    max_depth = args['max_depth']
    subsample = args['subsample']
    
    # xgboost 모델 정의
    model = xgb.XGBClassifier(
        learning_rate = learning_rate,
        max_depth = max_depth,
        subsample = subsample,
        random_state = 42
    )
    
    # 모델 학습
    model.fit(X_train, y_train)
    
    # 검증 데이터에 대한 예측 수행
    y_pred = model.predict(X_test)
    
    # 정확도 계산
    accuracy = accuracy_score(y_test, y_pred)
    
    return -accuracy # Hyperopt는 최적화를 위해 값을 최소화하므로 음수로 반환

# 탐색 공간 정의
space = {
    'learning_rate' : hp.uniform('learning_rate', 0.01, 0.3),
    'max_depth' : hp.choice('max_depth', range(1, 10)),
    'subsample' : hp.uniform('subsample', 0.5, 1.0)
}

# hyperopt를 사용하여 하이퍼 파라미터 최적화 및 출력
trials = Trials()
best = fmin(fn = objective, space = space, algo = tpe.suggest, max_evals = 100, trials = trials)

print('best hyperparameters : ', best)

# 최적화된 하이퍼 파라미터로 최종 모델 학습
best_model = xgb.XGBClassifier(
    learning_rate = best['learning_rate'],
    max_depth = best['max_depth'],
    subsample = best['subsample'],
    random_state = 10
)
best_model.fit(X_train, y_train)

# 최종 모델의 성능 평가
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print('final accuracy : ', accuracy)
# Out:
# 100%|█████████████████████████████████████████████| 100/100 [00:07<00:00, 13.85trial/s, best loss: -0.9824561403508771]
# best hyperparameters :  {'learning_rate': 0.06048296421915791, 'max_depth': 4, 'subsample': 0.6366215152608334}
# final accuracy :  0.9736842105263158

# %%
from hyperopt import hp
from xgboost import XGBClassifier


dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data = dataset.data, columns = dataset.feature_names)
cancer_df['target'] = dataset.target

X = cancer_df.iloc[:, : -1]
y = cancer_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 10)


xgb_search_space = {
    'learning_rate' : hp.uniform('learning_rate', 0.01, 0.2),
    'max_depth' : hp.quniform('max_depth', 5, 20, 1),
    'min_child_weight' : hp.quniform('min_child_weight', 1, 2, 1),
    'colsample_bytree' : hp.uniform('colsample_bytree', 0.5, 1)
}

# 목적 함수 설정
def objective_func(search_space) :
    xgb_clf = XGBClassifier(n_estimators = 100, max_depth = int(search_space['max_depth']),
                            min_child_weight = int(search_space['min_child_weight']),
                            learning_rate = search_space['learning_rate'],
                            colsample_bytree = search_space['colsample_bytree'],
                            eval_metric = 'logloss'
                           )
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring = 'accuracy', cv = 3)
    
    return {'loss' : -1 * np.mean(accuracy), 'status' : STATUS_OK}

# 하이퍼 파라미터 도출
trial_val = Trials()
best = fmin(fn = objective_func,
           space = xgb_search_space,
           algo = tpe.suggest,
           max_evals = 50,
           trials = trial_val, rstate = np.random.default_rng(seed = 9))

print('best : ', best, '\n')
print('colsample_bytree : {0}, learning_rate : {1}, max_depth : {2}, min_child_weight : {3} \n'
     .format(round(best['colsample_bytree'], 5), round(best['learning_rate'], 5), int(best['max_depth']),
            int(best['min_child_weight'])))

# 성능평가
xgb_wrapper = XGBClassifier(n_estimators = 400,
    learning_rate = round(best['learning_rate'], 5),
    max_depth = int(best['max_depth']),
    min_child_weight = int(best['min_child_weight']),
    colsample_bytree = round(best['colsample_bytree'], 5)
    )

evals = [(X_tr, y_tr), (X_val, y_val)]

xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds = 50, eval_metric = 'logloss',
               eval_set = evals, verbose = True)

prds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [00:12<00:00,  4.02trial/s, best loss: -0.9648106192633903]
# best :  {'colsample_bytree': 0.6128583597981321, 'learning_rate': 0.10075744671102672, 'max_depth': 5.0, 'min_child_weight': 1.0}
#
# colsample_bytree : 0.61286, learning_rate : 0.10076, max_depth : 5, min_child_weight : 1
#
# [0]	validation_0-logloss:0.61052	validation_1-logloss:0.60971
# [1]	validation_0-logloss:0.54034	validation_1-logloss:0.54231
# [2]	validation_0-logloss:0.48226	validation_1-logloss:0.48072
# [3]	validation_0-logloss:0.43265	validation_1-logloss:0.42732
# [4]	validation_0-logloss:0.38891	validation_1-logloss:0.37954
# [5]	validation_0-logloss:0.35286	validation_1-logloss:0.34103
# [6]	validation_0-logloss:0.31989	validation_1-logloss:0.30673
# [7]	validation_0-logloss:0.29231	validation_1-logloss:0.27715
# [8]	validation_0-logloss:0.26650	validation_1-logloss:0.25203
# [9]	validation_0-logloss:0.24354	validation_1-logloss:0.22907
# [10]	validation_0-logloss:0.22322	validation_1-logloss:0.21053
# [11]	validation_0-logloss:0.20503	validation_1-logloss:0.19244
# [12]	validation_0-logloss:0.18867	validation_1-logloss:0.17524
# [13]	validation_0-logloss:0.17321	validation_1-logloss:0.16058
# [14]	validation_0-logloss:0.16086	validation_1-logloss:0.14675
# [15]	validation_0-logloss:0.14860	validation_1-logloss:0.13545
# [16]	validation_0-logloss:0.13789	validation_1-logloss:0.12481
# [17]	validation_0-logloss:0.12855	validation_1-logloss:0.11520
# [18]	validation_0-logloss:0.11928	validation_1-logloss:0.10609
# [19]	validation_0-logloss:0.11120	validation_1-logloss:0.09939
# [20]	validation_0-logloss:0.10378	validation_1-logloss:0.09311
# [21]	validation_0-logloss:0.09710	validation_1-logloss:0.08746
# [22]	validation_0-logloss:0.09131	validation_1-logloss:0.08240
# [23]	validation_0-logloss:0.08638	validation_1-logloss:0.07819
# [24]	validation_0-logloss:0.08148	validation_1-logloss:0.07335
# [25]	validation_0-logloss:0.07676	validation_1-logloss:0.06853
# [26]	validation_0-logloss:0.07259	validation_1-logloss:0.06472
# [27]	validation_0-logloss:0.06878	validation_1-logloss:0.06048
# [28]	validation_0-logloss:0.06499	validation_1-logloss:0.05713
# [29]	validation_0-logloss:0.06151	validation_1-logloss:0.05373
# [30]	validation_0-logloss:0.05835	validation_1-logloss:0.05187
# [31]	validation_0-logloss:0.05544	validation_1-logloss:0.04867
# [32]	validation_0-logloss:0.05294	validation_1-logloss:0.04665
# [33]	validation_0-logloss:0.04995	validation_1-logloss:0.04517
# [34]	validation_0-logloss:0.04743	validation_1-logloss:0.04208
# [35]	validation_0-logloss:0.04533	validation_1-logloss:0.04098
# [36]	validation_0-logloss:0.04347	validation_1-logloss:0.03959
# [37]	validation_0-logloss:0.04156	validation_1-logloss:0.03817
# [38]	validation_0-logloss:0.03970	validation_1-logloss:0.03575
# [39]	validation_0-logloss:0.03819	validation_1-logloss:0.03446
# [40]	validation_0-logloss:0.03676	validation_1-logloss:0.03319
# [41]	validation_0-logloss:0.03549	validation_1-logloss:0.03286
# [42]	validation_0-logloss:0.03420	validation_1-logloss:0.03165
# [43]	validation_0-logloss:0.03288	validation_1-logloss:0.03011
# [44]	validation_0-logloss:0.03189	validation_1-logloss:0.02915
# [45]	validation_0-logloss:0.03074	validation_1-logloss:0.02835
# [46]	validation_0-logloss:0.02969	validation_1-logloss:0.02793
# [47]	validation_0-logloss:0.02870	validation_1-logloss:0.02779
# [48]	validation_0-logloss:0.02781	validation_1-logloss:0.02646
# [49]	validation_0-logloss:0.02700	validation_1-logloss:0.02566
# [50]	validation_0-logloss:0.02618	validation_1-logloss:0.02518
# [51]	validation_0-logloss:0.02545	validation_1-logloss:0.02468
# [52]	validation_0-logloss:0.02473	validation_1-logloss:0.02394
# [53]	validation_0-logloss:0.02415	validation_1-logloss:0.02364
# [54]	validation_0-logloss:0.02337	validation_1-logloss:0.02313
# [55]	validation_0-logloss:0.02282	validation_1-logloss:0.02324
# [56]	validation_0-logloss:0.02223	validation_1-logloss:0.02284
# [57]	validation_0-logloss:0.02169	validation_1-logloss:0.02276
# [58]	validation_0-logloss:0.02118	validation_1-logloss:0.02195
# [59]	validation_0-logloss:0.02071	validation_1-logloss:0.02189
# [60]	validation_0-logloss:0.02031	validation_1-logloss:0.02144
# [61]	validation_0-logloss:0.01987	validation_1-logloss:0.02068
# [62]	validation_0-logloss:0.01953	validation_1-logloss:0.02000
# [63]	validation_0-logloss:0.01911	validation_1-logloss:0.02011
# [64]	validation_0-logloss:0.01857	validation_1-logloss:0.02016
# [65]	validation_0-logloss:0.01808	validation_1-logloss:0.01979
# [66]	validation_0-logloss:0.01780	validation_1-logloss:0.01975
# [67]	validation_0-logloss:0.01743	validation_1-logloss:0.01970
# [68]	validation_0-logloss:0.01711	validation_1-logloss:0.01997
# [69]	validation_0-logloss:0.01675	validation_1-logloss:0.01952
# [70]	validation_0-logloss:0.01647	validation_1-logloss:0.01969
# [71]	validation_0-logloss:0.01623	validation_1-logloss:0.02001
# [72]	validation_0-logloss:0.01603	validation_1-logloss:0.01998
# [73]	validation_0-logloss:0.01581	validation_1-logloss:0.01988
# [74]	validation_0-logloss:0.01558	validation_1-logloss:0.01951
# [75]	validation_0-logloss:0.01538	validation_1-logloss:0.01909
# [76]	validation_0-logloss:0.01512	validation_1-logloss:0.01838
# [77]	validation_0-logloss:0.01492	validation_1-logloss:0.01811
# [78]	validation_0-logloss:0.01475	validation_1-logloss:0.01832
# [79]	validation_0-logloss:0.01452	validation_1-logloss:0.01848
# [80]	validation_0-logloss:0.01433	validation_1-logloss:0.01828
# [81]	validation_0-logloss:0.01415	validation_1-logloss:0.01842
# [82]	validation_0-logloss:0.01394	validation_1-logloss:0.01804
# [83]	validation_0-logloss:0.01374	validation_1-logloss:0.01836
# [84]	validation_0-logloss:0.01351	validation_1-logloss:0.01784
# [85]	validation_0-logloss:0.01331	validation_1-logloss:0.01746
# [86]	validation_0-logloss:0.01314	validation_1-logloss:0.01778
# [87]	validation_0-logloss:0.01302	validation_1-logloss:0.01757
# [88]	validation_0-logloss:0.01286	validation_1-logloss:0.01757
# [89]	validation_0-logloss:0.01273	validation_1-logloss:0.01758
# [90]	validation_0-logloss:0.01259	validation_1-logloss:0.01735
# [91]	validation_0-logloss:0.01246	validation_1-logloss:0.01737
# [92]	validation_0-logloss:0.01234	validation_1-logloss:0.01768
# [93]	validation_0-logloss:0.01218	validation_1-logloss:0.01734
# [94]	validation_0-logloss:0.01208	validation_1-logloss:0.01696
# [95]	validation_0-logloss:0.01196	validation_1-logloss:0.01676
# [96]	validation_0-logloss:0.01184	validation_1-logloss:0.01706
# [97]	validation_0-logloss:0.01174	validation_1-logloss:0.01698
# [98]	validation_0-logloss:0.01164	validation_1-logloss:0.01728
# [99]	validation_0-logloss:0.01153	validation_1-logloss:0.01689
# [100]	validation_0-logloss:0.01144	validation_1-logloss:0.01692
# [101]	validation_0-logloss:0.01136	validation_1-logloss:0.01712
# [102]	validation_0-logloss:0.01127	validation_1-logloss:0.01695
# [103]	validation_0-logloss:0.01118	validation_1-logloss:0.01682
# [104]	validation_0-logloss:0.01109	validation_1-logloss:0.01647
# [105]	validation_0-logloss:0.01101	validation_1-logloss:0.01636
# [106]	validation_0-logloss:0.01095	validation_1-logloss:0.01658
# [107]	validation_0-logloss:0.01086	validation_1-logloss:0.01622
# [108]	validation_0-logloss:0.01078	validation_1-logloss:0.01650
# [109]	validation_0-logloss:0.01073	validation_1-logloss:0.01669
# [110]	validation_0-logloss:0.01065	validation_1-logloss:0.01657
# [111]	validation_0-logloss:0.01058	validation_1-logloss:0.01648
# [112]	validation_0-logloss:0.01049	validation_1-logloss:0.01622
# [113]	validation_0-logloss:0.01037	validation_1-logloss:0.01596
# [114]	validation_0-logloss:0.01033	validation_1-logloss:0.01608
# [115]	validation_0-logloss:0.01026	validation_1-logloss:0.01575
# [116]	validation_0-logloss:0.01017	validation_1-logloss:0.01592
# [117]	validation_0-logloss:0.01011	validation_1-logloss:0.01593
# [118]	validation_0-logloss:0.01006	validation_1-logloss:0.01584
# [119]	validation_0-logloss:0.00999	validation_1-logloss:0.01571
# [120]	validation_0-logloss:0.00993	validation_1-logloss:0.01579
# [121]	validation_0-logloss:0.00986	validation_1-logloss:0.01583
# [122]	validation_0-logloss:0.00976	validation_1-logloss:0.01559
# [123]	validation_0-logloss:0.00973	validation_1-logloss:0.01571
# [124]	validation_0-logloss:0.00966	validation_1-logloss:0.01557
# [125]	validation_0-logloss:0.00963	validation_1-logloss:0.01541
# [126]	validation_0-logloss:0.00957	validation_1-logloss:0.01546
# [127]	validation_0-logloss:0.00950	validation_1-logloss:0.01516
# [128]	validation_0-logloss:0.00945	validation_1-logloss:0.01494
# [129]	validation_0-logloss:0.00938	validation_1-logloss:0.01509
# [130]	validation_0-logloss:0.00933	validation_1-logloss:0.01515
# [131]	validation_0-logloss:0.00926	validation_1-logloss:0.01504
# [132]	validation_0-logloss:0.00922	validation_1-logloss:0.01524
# [133]	validation_0-logloss:0.00914	validation_1-logloss:0.01509
# [134]	validation_0-logloss:0.00909	validation_1-logloss:0.01512
# [135]	validation_0-logloss:0.00907	validation_1-logloss:0.01495
# [136]	validation_0-logloss:0.00901	validation_1-logloss:0.01500
# [137]	validation_0-logloss:0.00895	validation_1-logloss:0.01489
# [138]	validation_0-logloss:0.00889	validation_1-logloss:0.01514
# [139]	validation_0-logloss:0.00887	validation_1-logloss:0.01500
# [140]	validation_0-logloss:0.00883	validation_1-logloss:0.01503
# [141]	validation_0-logloss:0.00880	validation_1-logloss:0.01487
# [142]	validation_0-logloss:0.00875	validation_1-logloss:0.01490
# [143]	validation_0-logloss:0.00873	validation_1-logloss:0.01501
# [144]	validation_0-logloss:0.00871	validation_1-logloss:0.01486
# [145]	validation_0-logloss:0.00868	validation_1-logloss:0.01496
# [146]	validation_0-logloss:0.00865	validation_1-logloss:0.01498
# [147]	validation_0-logloss:0.00860	validation_1-logloss:0.01475
# [148]	validation_0-logloss:0.00858	validation_1-logloss:0.01486
# [149]	validation_0-logloss:0.00854	validation_1-logloss:0.01489
# [150]	validation_0-logloss:0.00852	validation_1-logloss:0.01471
# [151]	validation_0-logloss:0.00850	validation_1-logloss:0.01457
# [152]	validation_0-logloss:0.00844	validation_1-logloss:0.01444
# [153]	validation_0-logloss:0.00841	validation_1-logloss:0.01432
# [154]	validation_0-logloss:0.00837	validation_1-logloss:0.01417
# [155]	validation_0-logloss:0.00833	validation_1-logloss:0.01407
# [156]	validation_0-logloss:0.00831	validation_1-logloss:0.01421
# [157]	validation_0-logloss:0.00829	validation_1-logloss:0.01408
# [158]	validation_0-logloss:0.00827	validation_1-logloss:0.01417
# [159]	validation_0-logloss:0.00825	validation_1-logloss:0.01403
# [160]	validation_0-logloss:0.00822	validation_1-logloss:0.01404
# [161]	validation_0-logloss:0.00820	validation_1-logloss:0.01395
# [162]	validation_0-logloss:0.00818	validation_1-logloss:0.01384
# [163]	validation_0-logloss:0.00815	validation_1-logloss:0.01396
# [164]	validation_0-logloss:0.00814	validation_1-logloss:0.01405
# [165]	validation_0-logloss:0.00812	validation_1-logloss:0.01391
# [166]	validation_0-logloss:0.00809	validation_1-logloss:0.01373
# [167]	validation_0-logloss:0.00804	validation_1-logloss:0.01364
# [168]	validation_0-logloss:0.00802	validation_1-logloss:0.01354
# [169]	validation_0-logloss:0.00801	validation_1-logloss:0.01364
# [170]	validation_0-logloss:0.00799	validation_1-logloss:0.01354
# [171]	validation_0-logloss:0.00797	validation_1-logloss:0.01342
# [172]	validation_0-logloss:0.00795	validation_1-logloss:0.01333
# [173]	validation_0-logloss:0.00793	validation_1-logloss:0.01344
# [174]	validation_0-logloss:0.00791	validation_1-logloss:0.01352
# [175]	validation_0-logloss:0.00789	validation_1-logloss:0.01340
# [176]	validation_0-logloss:0.00788	validation_1-logloss:0.01349
# [177]	validation_0-logloss:0.00786	validation_1-logloss:0.01363
# [178]	validation_0-logloss:0.00784	validation_1-logloss:0.01350
# [179]	validation_0-logloss:0.00782	validation_1-logloss:0.01339
# [180]	validation_0-logloss:0.00780	validation_1-logloss:0.01349
# [181]	validation_0-logloss:0.00779	validation_1-logloss:0.01340
# [182]	validation_0-logloss:0.00777	validation_1-logloss:0.01329
# [183]	validation_0-logloss:0.00775	validation_1-logloss:0.01316
# [184]	validation_0-logloss:0.00774	validation_1-logloss:0.01329
# [185]	validation_0-logloss:0.00772	validation_1-logloss:0.01338
# [186]	validation_0-logloss:0.00770	validation_1-logloss:0.01347
# [187]	validation_0-logloss:0.00769	validation_1-logloss:0.01335
# [188]	validation_0-logloss:0.00767	validation_1-logloss:0.01346
# [189]	validation_0-logloss:0.00765	validation_1-logloss:0.01334
# [190]	validation_0-logloss:0.00764	validation_1-logloss:0.01342
# [191]	validation_0-logloss:0.00762	validation_1-logloss:0.01333
# [192]	validation_0-logloss:0.00761	validation_1-logloss:0.01322
# [193]	validation_0-logloss:0.00759	validation_1-logloss:0.01332
# [194]	validation_0-logloss:0.00757	validation_1-logloss:0.01340
# [195]	validation_0-logloss:0.00756	validation_1-logloss:0.01331
# [196]	validation_0-logloss:0.00754	validation_1-logloss:0.01341
# [197]	validation_0-logloss:0.00753	validation_1-logloss:0.01349
# [198]	validation_0-logloss:0.00751	validation_1-logloss:0.01358
# [199]	validation_0-logloss:0.00750	validation_1-logloss:0.01346
# [200]	validation_0-logloss:0.00748	validation_1-logloss:0.01337
# [201]	validation_0-logloss:0.00747	validation_1-logloss:0.01347
# [202]	validation_0-logloss:0.00745	validation_1-logloss:0.01355
# [203]	validation_0-logloss:0.00744	validation_1-logloss:0.01346
# [204]	validation_0-logloss:0.00742	validation_1-logloss:0.01336
# [205]	validation_0-logloss:0.00741	validation_1-logloss:0.01345
# [206]	validation_0-logloss:0.00739	validation_1-logloss:0.01334
# [207]	validation_0-logloss:0.00738	validation_1-logloss:0.01346
# [208]	validation_0-logloss:0.00736	validation_1-logloss:0.01354
# [209]	validation_0-logloss:0.00735	validation_1-logloss:0.01363
# [210]	validation_0-logloss:0.00733	validation_1-logloss:0.01353
# [211]	validation_0-logloss:0.00732	validation_1-logloss:0.01363
# [212]	validation_0-logloss:0.00731	validation_1-logloss:0.01372
# [213]	validation_0-logloss:0.00729	validation_1-logloss:0.01360
# [214]	validation_0-logloss:0.00728	validation_1-logloss:0.01372
# [215]	validation_0-logloss:0.00727	validation_1-logloss:0.01361
# [216]	validation_0-logloss:0.00725	validation_1-logloss:0.01369
# [217]	validation_0-logloss:0.00724	validation_1-logloss:0.01381
# [218]	validation_0-logloss:0.00723	validation_1-logloss:0.01390
# [219]	validation_0-logloss:0.00721	validation_1-logloss:0.01377
# [220]	validation_0-logloss:0.00720	validation_1-logloss:0.01386
# [221]	validation_0-logloss:0.00719	validation_1-logloss:0.01393
# [222]	validation_0-logloss:0.00718	validation_1-logloss:0.01401
# [223]	validation_0-logloss:0.00716	validation_1-logloss:0.01410
# [224]	validation_0-logloss:0.00715	validation_1-logloss:0.01418
# [225]	validation_0-logloss:0.00714	validation_1-logloss:0.01406
# [226]	validation_0-logloss:0.00712	validation_1-logloss:0.01417
# [227]	validation_0-logloss:0.00711	validation_1-logloss:0.01408
# [228]	validation_0-logloss:0.00710	validation_1-logloss:0.01417
# [229]	validation_0-logloss:0.00709	validation_1-logloss:0.01426
# [230]	validation_0-logloss:0.00707	validation_1-logloss:0.01415
# [231]	validation_0-logloss:0.00706	validation_1-logloss:0.01423
# [232]	validation_0-logloss:0.00705	validation_1-logloss:0.01430
# [233]	validation_0-logloss:0.00704	validation_1-logloss:0.01439
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2072\826208706.py in <module>
#      63 pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
#      64
# ---> 65 get_clf_eval(y_test, preds, pred_proba)
#
# NameError: name 'get_clf_eval' is not defined
