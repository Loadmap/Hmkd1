# %% [markdown]
# with open('sample1.html', 'w', encoding = 'utf-8') as f :
#     f.write(
# '''
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset = 'UTF-8'>
#         <title>웹 디자인 시험작</title>
#         <style>
#             h1 {
#                 color : red :
#             }
#             nav ui li a {
#                 color: blue;
#             }
#             section h1, section p {
#                 text-align: left;
#             }
#         </style>
#         <script>
#             window.onload = function() {
#                 var menu1 = document.querySelector("#menu1");
#                 var menu2 = document.querySelector("#menu2");
#                 var menu3 = document.querySelector("#menu3");
#                 var menu4 = document.querySelector("#menu4");
#
#                 menu1.addEventListener("click", function() {
#                     var content = document.querySelector("#content1");
#                     content.style.display = "block";
#                 });
#
#                 menu2.addEventListener("click", function() {
#                     var content = document.querySelector("#content2");
#                     content.style.display = "block";
#                 });
#
#                 menu3.addEventListener("click", function() {
#                     var content = document.querySelector("#content3");
#                     content.style.display = "block";
#                 });
#                 menu4.addEventListener("click", function() {
#                     var content = document.querySelector("#content4");
#                     content.style.display = "block";
#                 });
#               };
#         </script>
#     </head>
#
#     <body>
#         <header>
#         <h2 style='color: maroon;'> HMKD1 Restaurnat</h2>
#             <nav>
#                 <ui>
#                     <li>
#                         <a href='#' id="menu1">Appetizer</a></li>
#                     <li>
#                         <a href='#' id="menu2">Entrée</a></li>
#                     <li>
#                         <a href='#' id="menu3">Salad or Cheese</a></li>
#                     <li>
#                         <a href='#' id="menu4">Dessert</a></li>
#                 </ui>
#             </nav>
#         </header>
#
#         <main>
#             <section>
#                 <h1 style='color: black;'><em>코스 요리 명칭</em></h1>
#                 <p>명칭을 입력하세요.</p>
#                 <input type='text' name='word' placeholder='명칭을 입력하세요.'>
#             </section>
#                 <table>
#                     <tbody>
#                         <br>
#                         <br>
#                         <tr>
#                             <th>명칭</th>
#                             <th>요리</th>
#                         <tr/>
#                         <tr>
#                             <td>Appetizer</td>
#                             <td>크림 수프</td>
#                         </tr>
#                         <tr>
#                             <td>Entrée</td>
#                             <td>스테이크</td>
#                         </tr>
#                         <tr>
#                             <td>Salad or Cheese</td>
#                             <td>연어 샐러드</td>
#                         </tr>
#                         <tr>
#                             <td>Dessert</td>
#                             <td>케이크</td>
#                         </tr>
#                     </tbody>
#                 <table>
#                 <img src = 'menu.jpg' alt = 'menu.jpg'>
#
#             <section id="content1" style="display:none;">
#                 <h3 style='color: green;'>Appetizer</h3>
#                 <p>초밥, 샐러드, 수프 등 <b>가벼운 음식</b>.</p>
#             </section>
#
#             <section id="content2" style="display:none;">
#                 <h3 style='color: red;'>Entrée</h3>
#                 <p>해산물, 파스타, 또는 리조또, 육류, 양념게장, 해물찜 등의 <b>주요 요리.</b></p>
#             </section>
#
#             <section id="content3" style="display:none;">
#                 <h3 style='color: yellowgreen;'>Salad or Cheese</h3>
#                 <p>샐러드, 치즈 또는 과일로 <b>중식을 대신하는 요리</b></p>
#             </section>
#
#             <section id="content4" style="display:none;">
#                 <h3 style='color: pink;'>Dessert</h3>
#                 <p>케이크, 파이, 아이스크림 등의 <b>달콤한 음식</b></p>
#             </section>
#         </main>
#
#         <footer>
#             <p><br>저작권 ©️ 2023 예시 회사. 모든 권리 보유.</p>
#         </footer>
#
#     </body>
# </html>
# ''')

# %%
with open('sample2.html', 'w', encoding = 'utf-8') as f :
    f.write(
'''
<!DOCTYPE html>
<html>
    <head>
        <meta charset = 'UTF-8'>
        <title>웹 디자인 시험작</title>
        <style>
            h1 {
                 style='color: black;'
            }
            nav ui li a {
                color: blue;
            }
            section h1, section p {
                text-align: left;
            }

            thead {
                style="background-color: lightgray;"
            }            
        </style>
        <script>
            window.onload = function() {
                var menu1 = document.querySelector("#menu1");
                var menu2 = document.querySelector("#menu2");
                var menu3 = document.querySelector("#menu3");
                var menu4 = document.querySelector("#menu4");

                menu1.addEventListener("click", function() {
                    var content = document.querySelector("#content1");
                    content.style.display = content.style.display === "none" ? "block" : "none";
                });

                menu2.addEventListener("click", function() {
                    var content = document.querySelector("#content2");
                    content.style.display = content.style.display === "none" ? "block" : "none";
                });

                menu3.addEventListener("click", function() {
                    var content = document.querySelector("#content3");
                    content.style.display = content.style.display === "none" ? "block" : "none";
                });
                menu4.addEventListener("click", function() {
                    var content = document.querySelector("#content4");
                    content.style.display = content.style.display === "none" ? "block" : "none";
                });                
              };
        
        </script>
    </head>
    
    <body>
        <header>
        <h2 style='color: maroon;'> HMKD1 Restaurnat</h2>
            <nav>
                <u1>
                    <li>
                        <a href='#' id="menu1">Appetizer</a></li>
                    <li>
                        <a href='#' id="menu2">Entrée</a></li>
                    <li>
                        <a href='#' id="menu3">Salad or Cheese</a></li>
                    <li>
                        <a href='#' id="menu4">Dessert</a></li>
                </u1>
            </nav>
        </header>
        
        </select>
        
        <main>
            <section>
                <h1><em>날짜 별 코스 요리</em></h1>
                <label for="date">Select date:</label>
                <input type='date' id='date' name='date' onchange='filterTable()' placeholder='날짜를 선택하세요.'>
            </section>
                <table>
                    <thead>
                        
                        <tr>
                            <th>Date</th>
                            <th>Appetizer</th>
                            <th>그림 1</th>
                            <th>Entrée</th>
                            <th>그림 2</th>
                            <th>Salad or Cheese</th>
                            <th>그림 3</th>
                            <th>Dessert</th>
                            <th>그림 4</th>
                        </tr>
                    </thead>
                    
                    <tbody>
                        <tr>
                            <td>2023-04-27</td>
                            <td style='color: green; text-align: center;'>크림 수프</td>
                            <td><img src = 'menuimage/menu1.4.27.jpg' alt = 'menu1.4.27.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>비프 스테이크<u></strong></td>
                            <td><img src = 'menuimage/menu2.4.27.jpg' alt = 'menu2.4.27.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>연어 샐러드</td>
                            <td><img src = 'menuimage/menu3.4.27.jpg' alt = 'menu3.4.27.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>케이크</td>
                            <td><img src = 'menuimage/menu4.4.27.jpg' alt = 'menu4.4.27.jpg' width="200" height="200"></td>
                        </tr>

                        <tr>
                            <td>2023-04-28</td>
                            <td style='color: green; text-align: center;'>토마토 수프</td>
                            <td><img src = 'menuimage/menu1.4.28.jpg' alt = 'menu1.4.28.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>새우 파스타<u></strong></td>
                            <td><img src = 'menuimage/menu2.4.28.jpg' alt = 'menu2.4.28.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>그린샐러드</td>
                            <td><img src = 'menuimage/menu3.4.28.jpg' alt = 'menu3.4.28.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>마카롱</td>
                            <td><img src = 'menuimage/menu4.4.28.jpg' alt = 'menu4.4.28.jpg' width="200" height="200"></td>                            
                        </tr>
                        
                        <tr>
                            <td>2023-04-29</td>
                            <td style='color: green; text-align: center;'>베이컨 수프</td>
                            <td><img src = 'menuimage/menu1.4.29.jpg' alt = 'menu1.4.29.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>버섯 크림 스파게티<u></strong></td>
                            <td><img src = 'menuimage/menu2.4.29.jpg' alt = 'menu2.4.29.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>오렌지 샐러드</td>
                            <td><img src = 'menuimage/menu3.4.29.jpg' alt = 'menu3.4.29.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>치즈케이크</td>
                            <td><img src = 'menuimage/menu4.4.29.jpg' alt = 'menu4.4.29.jpg' width="200" height="200"></td>                            
                        </tr>
                        
                        <tr>
                            <td>2023-04-30</td>
                            <td style='color: green; text-align: center;'>마늘과 로즈마리 파니니</td>
                            <td><img src = 'menuimage/menu1.4.30.jpg' alt = 'menu1.4.30.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>치킨<u></strong></td>
                            <td><img src = 'menuimage/menu2.4.30.jpg' alt = 'menu2.4.30.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>로메인 샐러드</td>
                            <td><img src = 'menuimage/menu3.4.30.jpg' alt = 'menu3.4.30.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>카라멜 체리 케이크</td>
                            <td><img src = 'menuimage/menu4.4.30.jpg' alt = 'menu4.4.30.jpg' width="200" height="200"></td>                            
                        </tr>
                       
                        <tr>
                            <td>2023-05-01</td>
                            <td style='color: green; text-align: center;'>그리스 샐러드</td>
                            <td><img src = 'menuimage/menu1.5.1.jpg' alt = 'menu1.5.1.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>토마호크 스테이크<u></strong></td>
                            <td><img src = 'menuimage/menu2.5.1.jpg' alt = 'menu2.5.1.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>그린빈 알몬드 샐러드</td>
                            <td><img src = 'menuimage/menu3.5.1.jpg' alt = 'menu3.5.1.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>크림 브륄레</td>
                            <td><img src = 'menuimage/menu4.5.1.jpg' alt = 'menu4.5.1.jpg' width="200" height="200"></td>
                        </tr>
                        
                        <tr>
                            <td>2023-05-02</td>
                            <td style='color: green; text-align: center;'>새우 크로켓</td>
                            <td><img src = 'menuimage/menu1.5.2.jpg' alt = 'menu1.5.2.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>이베리코<u></strong></td>
                            <td><img src = 'menuimage/menu2.5.2.jpg' alt = 'menu2.5.2.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>치즈 샐러드</td>
                            <td><img src = 'menuimage/menu3.5.2.jpg' alt = 'menu3.5.2.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>와플</td>
                            <td><img src = 'menuimage/menu4.5.2.jpg' alt = 'menu4.5.2.jpg' width="200" height="200"></td>
                        </tr>
                        
                        <tr>
                            <td>2023-05-03</td>
                            <td style='color: green; text-align: center;'>아페리티보</td>
                            <td><img src = 'menuimage/menu1.5.3.jpg' alt = 'menu1.5.3.jpg' width="200" height="200"></td>
                            <td style='color: red; text-align: center;'><strong><u>램 스테이크<u></strong></td>
                            <td><img src = 'menuimage/menu2.5.3.jpg' alt = 'menu2.5.3.jpg' width="200" height="200"></td>
                            <td style='color: yellowgreen; text-align: center;'>게살 샐러드</td>
                            <td><img src = 'menuimage/menu3.5.3.jpg' alt = 'menu3.5.3.jpg' width="200" height="200"></td>
                            <td style='color: pink; text-align: center;'>티라미수</td>
                            <td><img src = 'menuimage/menu4.5.3.jpg' alt = 'menu4.5.3.jpg' width="200" height="200"></td>
                        </tr>
                        
                    </tbody>
                </table>
                <script>
                    function filterTable() {
                        // Get selected date
                        var dateInput = document.getElementById("date");
                        var selectedDate = dateInput.value;

                        // Loop through table rows and hide/show based on date
                        var tableRows = document.getElementsByTagName("tr");
                        for (var i = 1; i < tableRows.length; i++) { // 첫 번째 행은 헤더이므로 제외
                            var rowDate = tableRows[i].getElementsByTagName("td")[0].innerHTML;
                            if (rowDate === selectedDate) {
                                tableRows[i].style.display = "table-row";
                            } else {
                                tableRows[i].style.display = "none";
                            }
                        }
                      }

                      // Date input에 변화가 생길 때마다 filterTable() 함수를 호출
                      var dateInput = document.getElementById("date");
                      dateInput.addEventListener("change", filterTable);
                </script>
                
                
            
            <section id="content1" style="display:none;">
                <h3 style='color: green;'>Appetizer</h3>
                <p>초밥, 샐러드, 수프 등 <b>가벼운 음식</b>.</p>
            </section>
            
            <section id="content2" style="display:none;">
                <h3 style='color: red;'>Entrée</h3>
                <p>해산물, 파스타, 또는 리조또, 육류, 양념게장, 해물찜 등의 <b>주요 요리.</b></p>
            </section>
            
            <section id="content3" style="display:none;">
                <h3 style='color: yellowgreen;'>Salad or Cheese</h3>
                <p>샐러드, 치즈 또는 과일로 <b>중식을 대신하는 요리</b></p>
            </section>
            
            <section id="content4" style="display:none;">
                <h3 style='color: pink;'>Dessert</h3>
                <p>케이크, 파이, 아이스크림 등의 <b>달콤한 음식</b></p>
            </section>
        </main>
        
        <footer>
            <p><br>저작권 ©️ 2023 예시 회사. 모든 권리 보유.</p>
        </footer>

    </body>
</html>
''')

# %% [markdown]
# Q. sample2에 input, table, img, span, div 태그를 추가하여 작성하세요.
# - input 태그는 텍스트 입력을 받는 폼 요소
# - table 태그는 표를 만드는 요소
# - img 태그는 이미지를 표시하는 요소
# - span 태그는 인라인 요소로서 다른 요소를 감싸는 역할
# - div 태그는 블록 요소로서 다른 요소를 감싸는 역할

# %% [markdown]
# <script>
#       window.onload = function() {
#         var menu1 = document.querySelector("#menu1");
#         var menu2 = document.querySelector("#menu2");
#         var menu3 = document.querySelector("#menu3");
#
#         menu1.addEventListener("click", function() {
#           var content = document.querySelector("#content1");
#           content.style.display = "block";
#         });
#
#         menu2.addEventListener("click", function() {
#           var content = document.querySelector("#content2");
#           content.style.display = "block";
#         });
#
#         menu3.addEventListener("click", function() {
#           var content = document.querySelector("#content3");
#           content.style.display = "block";
#         });
#       };
#     </script>
#
#     <main>
#       <section id="content1" style="display:none;">
#         <h1>메뉴 1 내용</h1>
#         <p>메뉴 1 내용이 들어갑니다.</p>
#       </section>
#       <section id="content2" style="display:none;">
#         <h1>메뉴 2 내용</h1>
#         <p>메뉴 2 내용이 들어갑니다.</p>
#       </section>
#       <section id="content3" style="display:none;">
#         <h1>메뉴 3 내용</h1>
#         <p>메뉴 3 내용이 들어갑니다.</p>
#       </section>
#     </main>

# %% [markdown]
# ### with open('sample3.html','w',encoding='utf8') as f:
# ###     f.write('''
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>문서 제목</title>
#     <style>
#       h1 {
#         color: red;
#       }
#       nav ul li a {
#         color: blue;
#       }
#       section h1, section p {
#         text-align: left;
#       }
#     </style>
#     <script>
#          window.onload = function() {
#            var menu1 = document.querySelector("#menu1");
#            var menu2 = document.querySelector("#menu2");
#            var menu3 = document.querySelector("#menu3");
#
#            menu1.addEventListener("click", function() {
#              var content = document.querySelector("#content1");
#              content.style.display = "block";
#            });
#
#            menu2.addEventListener("click", function() {
#              var content = document.querySelector("#content2");
#              content.style.display = "block";
#            });
#
#            menu3.addEventListener("click", function() {
#              var content = document.querySelector("#content3");
#              content.style.display = "block";
#            });
#          };
#     </script>
#   </head>
#   <body>
#
#     <header>
#       <h1>HMKD Restaurant</h1>
#       <nav>
#         <ul>
#           <li><a href="#" id="menu1">메뉴 1</a></li>
#           <li><a href="#" id="menu2">메뉴 2</a></li>
#           <li><a href="#" id="menu3">메뉴 3</a></li>
#         </ul>
#       </nav>
#     </header>
#     <main>
#       <section id="content1" style="display:none;">
#         <h1>메뉴 1 내용</h1>
#         <p>메뉴 1 내용이 들어갑니다.</p>
#       </section>
#       <section id="content2" style="display:none;">
#         <h1>메뉴 2 내용</h1>
#         <p>메뉴 2 내용이 들어갑니다.</p>
#       </section>
#       <section id="content3" style="display:none;">
#         <h1>메뉴 3 내용</h1>
#         <p>메뉴 3 내용이 들어갑니다.</p>
#       </section>
#     </main>
#     <footer>
#       <p>저작권 ©️ 2023 예시 회사. 모든 권리 보유.</p>
#     </footer>
#   </body>
# </html>
# ''')

# %% [markdown]
# ### 과제1

# %% [markdown]
# ### 과제 2
