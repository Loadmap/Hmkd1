# %% [markdown]
# ### requests 모듈
# - 파이썬에서 HTTP 요청을 보내고 응답을 받는 기능을 제공하는 라이브러리
# - 주요 메서드
#   - GET 메서드는 주어진 URL에서 데이터를 가져올 때 사용
#   - POST 메서드는 주어진 URL에 데이터를 보낼 때 사용
#   - PUT 메서드는 주어진 URL에 데이터를 업로드할 때 사용
#   - DELETE 메서드는 주어진 URL에서 데이터를 삭제할 때 사용

# %%
# get 메서드 사용 예제

import requests

response = requests.get('http://www.example.com/')

print(response.text)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
# 참고용 post 메서드 사용 예제

data = {'username' : 'user', 'password' : 'pass'}

response = requests.post('http://www.example.com/login', data = data)

print(response.status_code)
# Out:
# 404

# %% [markdown]
# ### urllib 하위 모듈
# - urllib.request: 이 모듈은 URL 열고 데이터를 읽어오는데 사용됩니다. urlopen() 함수를 사용하여 URL에서 데이터를 가져올 수 있습니다. 이 모듈에는 HTTP, FTP, HTTPS 및 파일 URL을 처리하는 다양한 클래스와 함수가 포함되어 있습니다.
#
# - urllib.parse: 이 모듈은 URL을 파싱하고 조작하는데 사용됩니다. urlparse() 함수를 사용하여 URL을 파싱하고, urlunparse() 함수를 사용하여 파싱된 URL을 다시 조립할 수 있습니다.
#
# - urllib.error: 이 모듈은 urllib.request 모듈에서 발생하는 예외를 처리하는데 사용됩니다. 이 모듈에는 다양한 예외 클래스들이 정의되어 있습니다.
#
# - urllib.robotparser: 이 모듈은 robots.txt 파일을 파싱하고 해석하는데 사용됩니다. RobotFileParser 클래스를 사용하여 robots.txt 파일을 파싱하고, can_fetch() 함수를 사용하여 주어진 로봇이 특정 URL에서 데이터를 가져올 수 있는지 여부를 확인할 수 있습니다.

# %%
# 데이터 가져오기

import urllib.request

url = 'http://www.example.com'

response = urllib.request.urlopen(url)
html = response.read()

print(html)
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
# url 파싱

url = 'http://www.example.com/search?q=python'
parsed_url = urllib.parse.urlparse(url)

print(parsed_url)
# Out:
# ParseResult(scheme='http', netloc='www.example.com', path='/search', params='', query='q=python', fragment='')

# %%
#  urllib.error.HTTPError 예외

import urllib.error

url = 'http://www.example.com/404'

try :
    response = urllib.request.urlopen(url)
    
except urllib.error.HTTPError as e :
    print('HTTP Error : ', e.code, e.reason)
# Out:
# HTTP Error :  404 Not Found

# %%
# status 및 getheader() 메서드를 사용하여 응답의 상태 코드 및 헤더를 확인

url = 'http://www.example.com'

response = urllib.request.urlopen(url)
print(response.status, '\n')
print(response.getheader('Content-Type'), '\n')
html = response.read()
print(html)
# Out:
# 200
#
# text/html; charset=UTF-8
#
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
# byte 를 text로 변환

url = 'http://www.example.com'

response = urllib.request.urlopen(url)
byte_data = response.read(100)
print(byte_data, '\n')
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <m'
#
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <m

# %%
from bs4 import BeautifulSoup

url = 'http://www.example.com'
response = urllib.request.urlopen(url)

soup = BeautifulSoup(response, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# <h1>Example Domain</h1>
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
# <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %% [markdown]
# ### BeautifulSoup
# - Python에서 HTML과 XML 문서를 파싱하여 원하는 정보를 추출하기 위한 라이브러리입니다.
# - BeautifulSoup은 HTML 문서를 파싱하여 파이썬 객체로 변환합니다. 이 파이썬 객체를 다루면서 원하는 정보를 추출할 수 있습니다.
# - BeautifulSoup을 사용하여 다음과 같은 작업을 수행할 수 있습니다.
#     - HTML/XML 문서를 파싱하여 파이썬 객체로 변환하기
#     - 파이썬 코드를 사용하여 문서 내부에서 데이터를 검색하고 추출하기
#     - CSS 선택자와 XPath 표현식을 사용하여 문서 내부에서 원하는 요소를 선택하기
#     - 선택한 요소의 속성과 값을 가져오기
#     - 문서 내부에서 링크, 이미지 등의 다른 요소를 추출하기
#     - 파싱된 데이터를 다시 HTML/XML 문서로 출력하기
# - BeautifulSoup에서 제공하는 다양한 메서드
#
#     - find() 메서드: HTML 문서에서 지정된 태그를 찾아내고 첫 번째로 발견된 태그를 반환합니다.
#
#     - find_all() 메서드: HTML 문서에서 지정된 태그를 찾아내고, 모든 발견된 태그를 리스트로 반환합니다.
#
#     - select_one() 메서드: CSS 선택자를 사용하여 HTML 문서에서 지정된 태그를 찾아내고, 첫번째로 발견된 태그를 리스트로 반환합니다.
#     - select() 메서드: CSS 선택자를 사용하여 HTML 문서에서 지정된 태그를 찾아내고, 모든 발견된 태그를 리스트로 반환합니다.
#
#     - prettify() 메서드: 파싱된 HTML 문서를 보기 좋게 정리하여 반환합니다.
#
#     - get() 메서드: HTML 태그의 속성(attribute) 값을 반환합니다.
#
#     - text 속성: HTML 태그 안에 있는 텍스트를 추출합니다.
#
#     - parent 속성: 현재 태그의 부모 태그를 반환합니다.
#
#     - children 속성: 현재 태그의 자식 태그들을 리스트로 반환합니다.

# %% [markdown]
# BeautifulSoup 라이브러리를 사용하여 DOM 객체로 변환하고, 필요한 데이터를 추출
# - 먼저 HTML 코드를 BeautifulSoup 객체로 변환한다. 이후, select 메서드를 사용하여 a 태그를 선택하고, href 속성을 사용하여 링크 URL을 추출한다. 이를 for 루프를 사용하여 출력할 수 있다.
# - 따라서, 이와 같이 BeautifulSoup 라이브러리를 사용하여 DOM을 탐색하고 필요한 데이터를 추출할 수 있으며, 이를 이용하여 파이썬 웹 크롤러를 구현
# - 위의 코드에서, HTML은 루트 요소인 $<html>$ 태그로 시작하며, 이 하위에 $<head>$ 태그와 $<body>$ 태그가 있다. $<html>$ 태그 안에는 문서 제목을 나타내는 $<title>$ 태그가 포함되어 있다.
# - $<body>$ 태그는 HTML 문서에서 가장 중요한 부분으로, 페이지 내용을 담고 있는 부분이다. $<body>$ 태그 안에는 $<h1>$ 태그와 $<ul>$ 태그가 포함되어 있으며, $<h1>$ 태그는 페이지의 제목을 나타낸다. $<ul>$ 태그는 목록을 나타내며, 여기에는 3개의 $<li>$ 태그가 포함되어 있으며, 각각의 $<li>$ 태그 안에는 $<a>$ 태그가 포함되어 있다.
#
# - 따라서, 위의 HTML 코드에서의 DOM 구조는 루트 요소인 $<html>$ 태그를 중심으로 계층 구조를 이루고 있으며, 이를 이용하여 자바스크립트나 파이썬 등의 스크립트 언어로 HTML 문서를 동적으로 조작하거나 데이터를 추출할 수 있다.

# %%
# html 코드를 파싱하여 beautifulsoup 객체로 만들기

html = """
<!DOCTYPE html>
<html>
<head>
<title>웹 크롤링 예시</title>
</head>
<body>
<h1>웹 크롤링 예시</h1>
<ul>
<li><a href="https://www.example.com">Example 1</a></li>
<li><a href="https://www.example.net">Example 2</a></li>
<li><a href="https://www.example.org">Example 3</a></li>
</ul>
</body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')

# 링크 url 추출하기

links = soup.select('a')

for link in links :
    
    print(link['href'])
# Out:
# https://www.example.com
# https://www.example.net
# https://www.example.org

# %%
with open('test.html', 'w') as f :
    f.write(
'''
<!doctype html>
<html>
  <head>
    <title>제목입니다</title>
  </head>
  <body>
    <p class="content">본문입니다.</p>
    <p>두 번째 단락입니다.</p>
    <a href="http://example.com">링크입니다.</a>
  </body>
</html>
''')

# %%
html = '''
<!doctype html>
<html>
  <head>
    <title>제목입니다</title>
  </head>
  <body>
    <p class="content">본문입니다.</p>
    <p>두 번째 단락입니다.</p>
    <a href="http://example.com">링크입니다.</a>
  </body>
</html>
'''

# %%
# soup 객체 생성

soup = BeautifulSoup(html, 'html.parser')
print(type(soup), '\n', soup)
# Out:
# <class 'bs4.BeautifulSoup'>
#
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>제목입니다</title>
# </head>
# <body>
# <p class="content">본문입니다.</p>
# <p>두 번째 단락입니다.</p>
# <a href="http://example.com">링크입니다.</a>
# </body>
# </html>

# %%
# find 사용 예제

title = soup.find('title')
print(title)
# Out:
# <title>제목입니다</title>

# %%
# find_all  사용예제

paragraphs = soup.find_all('p')

for p in paragraphs :
    print(p.text)
# Out:
# 본문입니다.
# 두 번째 단락입니다.

# %%
# select 메서드 사용 예제 href = hyper text reference 하이퍼 링크 생성할때 사용

link = soup.select('a')[0]

print(link['href'])
# Out:
# http://example.com

# %%
link = soup.select_one('a')

print(link['href'])
# Out:
# http://example.com

# %%
# prettify 메서드 사용

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    제목입니다
#   </title>
#  </head>
#  <body>
#   <p class="content">
#    본문입니다.
#   </p>
#   <p>
#    두 번째 단락입니다.
#   </p>
#   <a href="http://example.com">
#    링크입니다.
#   </a>
#  </body>
# </html>

# %%
# get 메서드 사용 예제

link = soup.select('a')[0]
print(link)
print(link.get('href'))
# Out:
# <a href="http://example.com">링크입니다.</a>
# http://example.com

# %%
# text 사용 예제

para = soup.find('p', {'class' : 'content'})
print(para)
print(para.text)
# Out:
# <p class="content">본문입니다.</p>
# 본문입니다.

# %%
# parent 사용 예제

para = soup.find('p', {'class' : 'content'})
print(para)
print(para.parent.name)
# Out:
# <p class="content">본문입니다.</p>
# body

# %%
# children 속성 사용 예제

para = soup.find('body')

for child in para :
    print(child)
# Out:
# <p class="content">본문입니다.</p>
#
#
# <p>두 번째 단락입니다.</p>
#
#
# <a href="http://example.com">링크입니다.</a>

# %%
html = """
<html><body>
  <h1>스크레이핑이란?</h1>
  <p>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""

soup = BeautifulSoup(html, 'html.parser')

h1 = soup.html.body.h1
p1 = soup.html.body.p
p2 = p1.next_sibling.next_sibling # 첫번째 next_sibling 선택되는 요소는 줄바꿈 문자와 같은 공백 문자열이기 때문에 두번 쓴다


print(h1)
print('h1 = ' + h1.string)
print('p = ' + p1.string)
print('p = ' + p2.string)
# Out:
# <h1>스크레이핑이란?</h1>
# h1 = 스크레이핑이란?
# p = 웹 페이지를 분석하는 것
# p = 원하는 부분을 추출하는 것

# %%
print('#title=' + h1.string)
print('#body=' + p2.string)
print(p1.text) # 첫번째만
print(p1.get_text()) # 전부다
# Out:
# #title=스크레이핑이란?
# #body=원하는 부분을 추출하는 것
# 웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것

# %%
# find_all

texts = soup.find_all('p')

for t in texts :
    print(t.text)
# Out:
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것

# %%
html = """
<html><body>
  <ul>
    <li><a href="http://www.naver.com">naver</a></li>
    <li><a href="http://www.daum.net">daum</a></li>
  </ul>
</body></html>
"""

soup = BeautifulSoup(html, 'html.parser')

links = soup.find_all('a')

for a in links :
    href = a.attrs['href']
    text = a.string
    print(text, '>', href)
# Out:
# naver > http://www.naver.com
# daum > http://www.daum.net

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')
contents = soup.find('body')

for child in contents.children :
    print(child)
# Out:
# <p align="center" class="a"> text1</p>
#
#
# <p align="center" class="b"> text2</p>
#
#
# <p align="center" class="c"> text3</p>
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
# body 의 자손은 p div img

for d in contents.descendants :
    print(d)
# Out:
# <p align="center" class="a"> text1</p>
#  text1
#
#
# <p align="center" class="b"> text2</p>
#  text2
#
#
# <p align="center" class="c"> text3</p>
#  text3
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
#
#
# <img height="200" src="/source" width="300"/>

# %%
img_tag = contents.find('img')

print(img_tag, '\n')
print(img_tag.parent)
# Out:
# <img height="200" src="/source" width="300"/>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
print(list(img_tag.parents))
# Out:
# [<div>
# <img height="200" src="/source" width="300"/>
# </div>, <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>,
# <head>
# <title>crawler</title>
# </head>
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# ]

# %%
# 태그 객체

print(contents.div.img)
# Out:
# <img height="200" src="/source" width="300"/>

# %%
soup = BeautifulSoup(html, 'html.parser')
contents = soup.find('body')

print(contents, '\n')

img_tag = contents.find('img')
print(img_tag.find_parent('body'), '\n')
print(img_tag.find_parent('div'))
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
p_tag = soup.find('p', class_ = 'c') # class 가 키워드 여서

print(p_tag)
# Out:
# <p align="center" class="c"> text3</p>

# %%
# find_previous_sibling() : 바로 이전 형제 노드 검색
# find_previous_siblings() : 모든 형제 노드 검색

print(p_tag.find_previous_sibling())
print(p_tag.find_previous_siblings())
# Out:
# <p align="center" class="b"> text2</p>
# [<p align="center" class="b"> text2</p>, <p align="center" class="a"> text1</p>]

# %%
with open('test2.html','w') as f:
    f.write(
'''
<!doctype html>
<html>
<body>
<div id="meigen">
  <h1>위키북스 도서</h1>
  <ul class="items">
    <li>유니티 게임 이펙트 입문</li>
    <li>스위프트로 시작하는 아이폰 앱 개발 교과서</li>
    <li>모던 웹사이트 디자인의 정석</li>
  </ul>
</div>
</body>
</html>
''')

# %%
html = '''
<!doctype html>
<html>
<body>
<div id="meigen">
  <h1>위키북스 도서</h1>
  <ul class="items">
    <li>유니티 게임 이펙트 입문</li>
    <li>스위프트로 시작하는 아이폰 앱 개발 교과서</li>
    <li>모던 웹사이트 디자인의 정석</li>
  </ul>
</div>
</body>
</html>
'''

soup = BeautifulSoup(html, 'html.parser')

h1 = soup.select_one('div#meigen > h1').string
print('h1 = ', h1)

li_list = soup.select('div#meigen > ul.items > li')

for li in li_list :
    print('li = ', li.string)
# Out:
# h1 =  위키북스 도서
# li =  유니티 게임 이펙트 입문
# li =  스위프트로 시작하는 아이폰 앱 개발 교과서
# li =  모던 웹사이트 디자인의 정석

# %%
fp = open('books.html', encoding = 'utf-8')
soup = BeautifulSoup(fp, 'html.parser')
print(soup, '\n')

sel = lambda q : print(soup.select_one(q).string, '\n')
sel('#nu')
sel('li#nu')
sel('ul > li#nu')
sel('#bible #nu')
sel('#bible > #nu')
sel('ul#bible > li#nu')
sel("li[id = 'nu']")
sel('li:nth-of-type(4)')

print(soup.select('li')[3].string)
print(soup.find_all('li')[3].string)
# Out:
# <ul id="bible">
# <li id="ge">Genesis</li>
# <li id="ex">Exodus</li>
# <li id="le">Leviticus</li>
# <li id="nu">Numbers</li>
# <li id="de">Deuteronomy</li>
# </ul>
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
#
# Numbers
# Numbers

# %% [markdown]
# ### 과제1
#
# 아래와 같이 출력하세요
#
# - 레몬
# - 아보카도
# - 아보카도
# - 아보카도
# - 아보카도
# - 아보카도

# %%
from bs4 import BeautifulSoup 
fp = open("fruits-vegetables.html", encoding="utf-8")
soup = BeautifulSoup(fp, "html.parser")

print(soup, '\n')

fruits = lambda q : print(soup.select_one(q).string)
fruits('li.yellow')
fruits('li.black[data-lo="us"]')
fruits('ul#ve-list > li:nth-child(4)') # ul#ve-list 내부의 네 번째 li 요소
fruits('ul#ve-list > li:nth-of-type(4)')
print(soup.select('li')[7].string)
print(soup.find_all('li')[7].string)
# Out:
# <html>
# <body>
# <div id="main-goods" role="page">
# <h1>과일과 야채</h1>
# <ul id="fr-list">
# <li class="red green" data-lo="ko">사과</li>
# <li class="purple" data-lo="us">포도</li>
# <li class="yellow" data-lo="us">레몬</li>
# <li class="yellow" data-lo="ko">오렌지</li>
# </ul>
# <ul id="ve-list">
# <li class="white green" data-lo="ko">무</li>
# <li class="red green" data-lo="us">파프리카</li>
# <li class="black" data-lo="ko">가지</li>
# <li class="black" data-lo="us">아보카도</li>
# <li class="white" data-lo="cn">연근</li>
# </ul>
# </div>
# </body>
# </html>
#
# 레몬
# 아보카도
# 아보카도
# 아보카도
# 아보카도
# 아보카도

# %% [markdown]
# ### requests 와 BeautifulSoup 을 사용하여 크롤링 하는 예제

# %%
url = 'http://www.example.com/'

response = requests.get(url)
html = response.text
print(html, '\n')

soup = BeautifulSoup(html, 'html.parser')

title = soup.find('title').text
para = soup.find_all('p')
links = [a['href'] for a in soup.select('a')]

print('Title:', title, '\n')
print('para : ')

for p in para :
    print('-', p.text)

print('Links : ')

for link in links :
    print('-', link)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>
#
#
# Title: Example Domain
#
# para :
# - This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.
# - More information...
# Links :
# - https://www.iana.org/domains/example

# %% [markdown]
# ### urllib 과 BeautifulSoup 사용하여 웹 크롤링

# %%
from urllib.request import urlopen

url = 'http://www.example.com/'

response = urlopen(url)
print(response, '\n')

soup = BeautifulSoup(response, 'html.parser')

title = soup.find('title').text
para = soup.find_all('p')
links = [a['href'] for a in soup.select('a')]

print('Title : ', title)
print('para : ')
for p in para :
    print('-', p.text)

print('Links : ')
for link in links :
    print('-', link)
# Out:
# <http.client.HTTPResponse object at 0x000001921BB26FD0>
#
# Title :  Example Domain
# para :
# - This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.
# - More information...
# Links :
# - https://www.iana.org/domains/example

# %%
import urllib.request as req

url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

res = req.urlopen(url)

soup = BeautifulSoup(res, 'html.parser')

soup
# Out:
# C:\Users\h\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2023년 05월 01일 (월)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2023년 05월 01일 (월)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>202305010600</tm>
# <wf><![CDATA[○ (강수) 4일(목) 전남권과 경남권, 제주도에 비가 오겠습니다.<br />○ (기온) 5일(금)~6일(토) 아침 기온은 14~18도로 평년(최저기온 9~14도)보다 높겠고, 그 밖의 날의 아침 기온은 8~15도로 평년과 비슷하겠습니다.<br />          7일(일) 낮 기온은 18~22도로 평년(최고기온 21~25도)보다 낮겠고, 그 밖의 날의 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.<br />○ (주말전망) 6일(토)~7일(일) 전국이 대체로 흐리겠습니다. 아침 기온은 11~18도, 낮 기온은 18~23도가 되겠습니다.<br /><br />* 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>인천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>수원</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>파주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>이천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>평택</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>춘천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>원주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영동</province>
# <city>강릉</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>대전</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>세종</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>홍성</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>청주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>충주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>영동</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>7</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>7</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>7</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>목포</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>여수</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>순천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광양</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>나주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>전주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>군산</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>정읍</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# ...
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>대구</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>안동</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>포항</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>경주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울진</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울릉도</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>16</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>16</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>제주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>서귀포</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-08 12:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-11 00:00</tmef>
# <wf>맑음</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# </body>
# </description>
# </item>
# </channel>
# </rss>

# %%
title = soup.find('title').string
wf = soup.find('wf').string

print(title, '\n')
print(wf)
# Out:
# 기상청 육상 중기예보
#
# ○ (강수) 4일(목) 전남권과 경남권, 제주도에 비가 오겠습니다.<br />○ (기온) 5일(금)~6일(토) 아침 기온은 14~18도로 평년(최저기온 9~14도)보다 높겠고, 그 밖의 날의 아침 기온은 8~15도로 평년과 비슷하겠습니다.<br />          7일(일) 낮 기온은 18~22도로 평년(최고기온 21~25도)보다 낮겠고, 그 밖의 날의 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.<br />○ (주말전망) 6일(토)~7일(일) 전국이 대체로 흐리겠습니다. 아침 기온은 11~18도, 낮 기온은 18~23도가 되겠습니다.<br /><br />* 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.

# %%
import requests
import re

url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

data = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')
wf = soup.find('wf').text

print(wf)

wf = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?', wf))
wf
# Out:
# ○ (강수) 4일(목) 전남권과 경남권, 제주도에 비가 오겠습니다.<br />○ (기온) 5일(금)~6일(토) 아침 기온은 14~18도로 평년(최저기온 9~14도)보다 높겠고, 그 밖의 날의 아침 기온은 8~15도로 평년과 비슷하겠습니다.<br />          7일(일) 낮 기온은 18~22도로 평년(최고기온 21~25도)보다 낮겠고, 그 밖의 날의 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.<br />○ (주말전망) 6일(토)~7일(일) 전국이 대체로 흐리겠습니다. 아침 기온은 11~18도, 낮 기온은 18~23도가 되겠습니다.<br /><br />* 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.
# '(강수) 4일(목) 전남권과 경남권, 제주도에 비가 오겠습니다.(기온) 5일(금)~6일(토) 아침 기온은 14~18도로 평년(최저기온 9~14도)보다 높겠고, 그 밖의 날의 아침 기온은 8~15도로 평년과 비슷하겠습니다. 7일(일) 낮 기온은 18~22도로 평년(최고기온 21~25도)보다 낮겠고, 그 밖의 날의 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.(주말전망) 6일(토)~7일(일) 전국이 대체로 흐리겠습니다. 아침 기온은 11~18도, 낮 기온은 18~23도가 되겠습니다. 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.'

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'

html = rq.urlopen(url)
soup = BeautifulSoup(html, 'lxml')
print(soup, '\n')

text = soup.find('p')
text = text.get_text()
text
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 09:04:17 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000811585?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/088/2023/04/30/811585.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000811585?sid=100">다큐 '문재인입니다' 첫 상영…"5년 성취 허망" 발언 빠지고 '텃밭 생활' 부각</a>
# <div class="cluster_text_lede">문재인 전 대통령의 퇴임 후 일상을 다룬 다큐멘터리 영화 '문재인입니다(5월 10일 개봉)'가 지난 29일 전주국제영화제에서 처음 상영됐다. 개봉 전 선 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000811585',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003276807',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276807?sid=100">"5년 성취 무너져 허망" 文발언 빠져…다큐 '문재인입니다' 보니</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054330',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054330?sid=100">'자연인 문재인'의 일상…다큐 '문재인입니다' 첫 공개</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137230',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137230?sid=100">전주국제영화제, ‘문재인입니다’ 공개…“5년간 이룬 성취 무너져” 발언은 빠져</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300550_00000022&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=088&amp;aid=0000811585"><span class="cluster_foot_more_icon_num">26</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833049?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11833049.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833049?sid=100">워싱턴 선언, 북핵 우려 해소·핵파트너 도약…신냉전외교 시험대[尹방미 결산]</a>
# <div class="cluster_text_lede">기사내용 요약 워싱턴선언, 북핵 맞서 확장억제 획기적 강화 한국전쟁부터 BTS까지…동맹의 '역사'와 '미래' 한미일 대 북중러 신냉전 대결…외교 시험대  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833049',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839331',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839331?sid=100">대통령실 "한미상호방위조약, 핵 포함하는 개념으로 업그레이드"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898009',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">대통령실 “핵 포함한 개념으로 한미상호방위조약 개선”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833187',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833187?sid=100">한미, 포괄적 전략동맹 격상…확장억제 명문화[尹정부 개혁 1년]</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833049"><span class="cluster_foot_more_icon_num">21</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005004939?sid=100">"한미회담 끝나기만 기다렸다"..北 ICBM 등 쏠 일만 남았다?</a>
# <div class="cluster_text_lede">윤석열 대통령이 4월30일 워싱턴 선언 등 안보와 경제분야 성과를 도출한 5박 7일간의 미국 국빈방문 일정을 마치고 귀국하면서 이후 북한의 미사일 도발 등 추가 도발이 이어질 가능성에 관심이 쏠린다. 북한은 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005004939',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001604989',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001604989?sid=100">김여정, 워싱턴선언에 반발하며 ‘핵 선제타격’ 위협</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220614',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220614?sid=100">북 “핵전쟁 기정사실화…비싼 대가 치를 것” 위협 수위 높여</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000596391',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596391?sid=100">북한, 연일 '워싱턴 선언' 비난…릴레이 도발 나서나</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281750_00002015&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0005004939"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123802?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2023/04/30/5123802.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123802?sid=100">1일 윤리위 여는 국민의힘, 김재원 중징계할까?</a>
# <div class="cluster_text_lede">‘설화 논란’ 김 최고위원 중징계 전망 징계 결과에 따라 김기현 체제 후폭풍 5.18 기념식 참석 전 징계 판가름 날 듯 태영호 최고위원 징계여부도 관심 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005123802',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002569322',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">문화일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569322?sid=100">국민의힘 윤리위 1일 첫 회의… ‘김재원 중징계’ 나오나</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475790',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475790?sid=100">국민의힘, 오늘 윤리위 첫 회의…김재원·태영호 징계 여부 심의</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881684',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881684?sid=100">野 '태영호·김재원 징계' 촉구에 與 "위대한 정신 승리의 백미"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0005123802"><span class="cluster_foot_more_icon_num">45</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001604965?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/04/30/1604965.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001604965?sid=100">尹, 하버드 대담서 “워싱턴선언, 나토 다자약정보다 실효성 있다”</a>
# <div class="cluster_text_lede">윤석열 대통령은 28일(현지시간) 보스턴 하버드대 케네디스쿨 연설 후 조지프 나이 하버드대 석좌교수 및 학생들과의 대담에서 여러 외교안보 현안에 대한 입 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001604965',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605104?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/01/1605104.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605104?sid=100">“워싱턴 선언, 나토 약정보다 실효적… 한·미 방위 업그레이드”</a>
# <div class="cluster_text_lede">윤석열 대통령은 28일(현지시간) 보스턴 하버드대 케네디스쿨 연설 후 조지프 나이 하버드대 석좌교수 및 학생들과의 대담에서 여러 외교안보 현안에 대한 입 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605104',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290820_00000035&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001604965"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013912511?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/04/30/13912511.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013912511?sid=100">'5월 독립운동가'에 가네코 후미코·후세 다쓰지 선정</a>
# <div class="cluster_text_lede">일본인으로서 정의의 편에서 보편적 인류애에 헌신 일본인이었지만 대한민국 독립을 위해 헌신한 가네코 후미코(金子文子)와 후세 다쓰지(布施辰治) 선생이 '5 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013912511',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185042?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/04/30/4185042.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185042?sid=100">'5월의 독립운동가'에 日가네코 후미코·후세 다쓰지 선정</a>
# <div class="cluster_text_lede">일본인이지만 대한민국 독립을 위해 헌신한 가네코 후미코(金子文子)와 후세 다쓰지(布施辰治) 선생이 ‘5월의 독립운동가’로 선정됐다. 30일 국가보훈처는  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185042',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301020_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013912511"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276984?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3276984.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276984?sid=100">尹 지지율 1.9%p 오른 34.5%…'방미 효과' 4주만에 반등 [리얼미터]</a>
# <div class="cluster_text_lede">1일 윤석열 대통령 국정 수행 지지도가 미국 국빈 방문과 맞물려 4주만에 반등했다는 여론조사 결과가 나왔다. 리얼미터가 미디어트리뷴 의뢰로 지난달 24일 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003276984',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833189?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833189.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833189?sid=100">민주당 1.0%p 내린  44.7%…국민의힘 35.2%[리얼미터]</a>
# <div class="cluster_text_lede">더불어민주당의 지지율이 직전 조사보다 1.0% 포인트 하락한 44.7%로 나타났다. 국민의힘은 0.7% 포인트 오른 35.2%를 기록했다. 여론조사기관  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833189',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003276984"><span class="cluster_foot_more_icon_num">16</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002637908?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/028/2023/04/30/2637908.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002637908?sid=100">미 국방부, 한 달전 실시 ‘한-미 핵불능화 훈련’ 공개</a>
# <div class="cluster_text_lede">미국 국방부가 최근 한-미 양국의 핵불능화 부대가 한반도에서 연합 훈련한 사실을 공개했다. 미국이 본토의 핵불능화팀을 한국으로 파견해 우리 군과 연합 훈 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002637908',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한겨레</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494577?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/04/30/3494577.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494577?sid=100">한미, 지난달 FS 연합연습때 유사시 北진입 핵불능화 훈련 실시</a>
# <div class="cluster_text_lede">한미가 3월 프리덤실드(FS) 연합연습 기간 유사시 북한에 진입해 핵무기를 불능화하는 훈련을 실시한 것으로 확인됐다. 미 국방부는 한미 정상회담 당일인  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494577',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304292020_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002637908"><span class="cluster_foot_more_icon_num">13</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808071?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/05/01/3808071.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808071?sid=100">이재명 “박광온과 합쳐 반드시 총선 승리...역사적 소명 주어져”</a>
# <div class="cluster_text_lede">박 신임 원내대표, ‘이낙연 캠프’ 총괄본부장을 지내 친이낙연계 핵심으로 분류 "품격 있는 민주당의 문화를 앞장서서 지키겠다" 박광온 더불어민주당 신임  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003808071',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137187?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/04/30/2137187.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137187?sid=100">이재명 “박광온과 ‘총선승리’ 역사적 소명”</a>
# <div class="cluster_text_lede">이재명 더불어민주당 대표는 30일 “저와 박광온 (신임) 원내대표에게는 함께 힘을 합쳐 총선에서 반드시 승리해 우리 사회의 추락을 저지해야 할 역사적 소 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137187',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301520_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003808071"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494564?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/04/30/3494564.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494564?sid=100">“백악관 또 와달라” 한미정상 부부 멈추게한 아이들의 ‘아리랑’</a>
# <div class="cluster_text_lede">조 바이든 미국 대통령 부부가 최근 국빈 방문한 윤석열 대통령과 김건희 여사를 환영하는 자리에서 한인 아이들의 노래를 듣고 감동했다는 소식이 전해졌다.  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494564',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123762?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2023/04/30/5123762.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123762?sid=100">“백악관에 또 와달라”…한미정상 부부에 감동 전한 한인 아이들</a>
# <div class="cluster_text_lede">“백악관에 또 와줄 수 있겠니? (질 바이든 여사) 바이든 대통령 부부가 최근 국빈 방문한 윤석열 대통령과 김건희 여사를 환영하는 자리에서 한인 아이들로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005123762',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300850_00000068&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=020&amp;aid=0003494564"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736880?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/04/30/736880.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736880?sid=100">홍준표 “대통령실도 물고 들어간 전광훈, 연결고리 끊어라”</a>
# <div class="cluster_text_lede">홍준표 대구시장이 “대통령실로부터 전화를 받았다”고 주장한 전광훈 사랑제일교회 목사와의 관계를 단절하라고 국민의힘에 촉구했다. 홍 시장은 29일 자신의  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000736880',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357554?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/081/2023/04/30/3357554.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357554?sid=100">홍준표 “‘하나님도 맞는다’는 전광훈이 목사인가요?”</a>
# <div class="cluster_text_lede">홍준표 대구시장은 29일 국민의힘 지도부를 향해 전광훈 사랑제일교회 목사를 단절하라고 주문했다. 홍준표 시장은 이날 페이스북에 “하나님도 잘못하면 나한테 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003357554',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281540_00000420&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000736880"><span class="cluster_foot_more_icon_num">19</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797773?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/04/30/2797773.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797773?sid=100">박지원 "`아메리칸 파이` 尹-바이든 듀엣으로 하려했다…`바보 대통령실`"</a>
# <div class="cluster_text_lede">박지원 전 국정원장은 30일 윤석열 대통령이 지난 26일(현지시간) 백악관 국빈만찬에서 부른 미 포크록 가수 돈 맥플린의 '아메리칸 파이'(America …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797773',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494589?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/04/30/3494589.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494589?sid=100">박지원 ‘尹-바이든 듀엣 조율’ 주장에…대통령실 “반국가적 작태”</a>
# <div class="cluster_text_lede">대통령실은 30일 백악관 만찬에서 윤석열 대통령이 부른 ‘아메리칸 파이’와 관련한 박지원 전 국가정보원장의 주장에 대해 “반국가적 작태”라고 일축했다.  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494589',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301100_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=029&amp;aid=0002797773"><span class="cluster_foot_more_icon_num">35</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913450?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913450.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913450?sid=100">與 '청년정책 컨트롤타워' 오늘 출범…청년정책 집중 발굴</a>
# <div class="cluster_text_lede">국민의힘의 청년 정책을 총괄하는 '청년정책네트워크'가 당 대표 직속 기구로 1일 공식 출범한다. 김기현 대표 등 국민의힘 지도부는 이날 최고위원회의에서  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913450',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137175?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/04/30/2137175.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137175?sid=100">이민근 안산시장, 강한 청년드라이브 정책 건다</a>
# <div class="cluster_text_lede">안산시(시장 이민근)는 지난 28일 오후 시청 상황실에서 제2회 청년정책위원회 정기회의를 개최했다고 30일 밝혔다 이날 개최된 위원회 정기회의에서는 ▷올 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137175',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301730_00000474&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913450"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779233?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/04/30/6779233.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779233?sid=100">이준석 "방미 성과 제대로 설명해야…국민 냉정하게 평가할 것"</a>
# <div class="cluster_text_lede">이준석 전 국민의힘 대표는 30일 5박 7일간의 미국 국빈 방문을 마치고 귀국한 윤석열 대통령을 향해 "잘했으면 좋겠다"면서도 "대일 외교부터 한미 정상 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779233',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832969?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832969.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832969?sid=100">이준석 전 대표, 블로그 '고공행진' 오프라인 행사 참석 [뉴시스Pic]</a>
# <div class="cluster_text_lede">이준석 전 국민의힘 당 대표를 중심으로 한 블로그 '고공행진' 오프라인 행사가 30일 신촌의 한 주점에서 열렸다. 이날 행사는 이준석 전 당 대표가 참석 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832969',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301740_00000016&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779233"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252843?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/04/30/5252843.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005
</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/032/0003220689?sid=103" title="5월 첫날 맑고 포근··· 큰 일교차 주의해야">5월 첫날 맑고 포근··· 큰 일교차 주의해야</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000596430?sid=103" title="[날씨] 따뜻한 봄날·큰 일교차…강원 영동 강풍 속 화재주의">[날씨] 따뜻한 봄날·큰 일교차…강원 영동 강풍 속 화재주의</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>
# 'AiRS추천으로 구성된 뉴스를 제공합니다.'

# %% [markdown]
# ### 과제 2
#
# url = 'http://news.naver.com' 에서 문서를 가져와서 한글만 출력하세요. (최대한 텍스트 형태)
#
# - requests 사용
# - urllib 사용

# %%
# request

url = 'http://news.naver.com'

data = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')
# print(soup)

ko = ' '.join(re.findall(r'[가-힣]+', soup.get_text()))

print(ko)
# Out:
# 네이버 뉴스 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 뉴스스탠드 라이브러리 콘텐츠 월 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자 연재 구독설정 속보 돈봉투 의혹 송영길 경선 캠프 관계자들 추가 압수수색 세계일보 내용작성전 올해 월 무역적자 억달러 작년의 차지 헤럴드경제 내용작성전 검찰 민주당 돈봉투 송영길 경선캠프 관계자 추가 압수수색 대전일보 내용작성전 월 무역수지 억 만달러 적자 개월 연속 먹구름 한국일보 월 무역적자 억 만달러 개월 연속 적자 머니 내용작성전 돈봉투 의혹 송영길 캠프 관계자들 추가 압수수색 노컷뉴스 월 수출 억달러 년 전보다 감소 경향신문 월 반도체 수출 전년 무역수지 개월 연속 적자 아시아경제 내용작성전 월 수출 무역적자 억달러 이데일리 검찰 송영길 경선 캠프 관계자들 추가 압수수색 디지털타임스 내용작성전 수출 개월 연속 감소 개월째 무역적자 연합뉴스 월 수출 전년 억 달러 무역적자 뉴시스 내용작성전 월 수출 전년 감소 무역적자 억 달러 개월 연속 뉴스 내용작성전 검찰 송영길 경선 캠프 관계자 추가 압수수색 검찰 돈봉투의혹 송영길캠프 지역본부장 추가 압수수색 머니투데이 내용작성전 속보 닫기 농민신문 월 일 구독 환경오염 해결사 주범 의 두 얼굴 미래는 이미 우리 곁에 와 있다 단지 널리 퍼져 있지 않을 뿐이다 공상과학 소설가이자 미래학자인 윌리엄 깁슨이 년 월 미국의 한 라디오 방송에서 한 말입니다 미래가 성큼 다가왔지만 모두가 뉴스 월 일 구독 주가급등 후 하따까지 이 작전 어디서 봤더라 손엄지의 주식살롱 최근 무더기 하한가 로 드러난 주가조작 사태는 지난 년 월에 개봉한 영화 작전 을 떠오르게 합니다 결국 주식시장은 년이 지나고도 달라진 게 없었는데요 오히려 차익결제거래 라는 레버리지 상품 비즈워치 월 일 구독 자녀장려금 준다는데 받을 아이가 없다 자녀장려금제도의 지속적인 수급요건 완화에도 그 수급자수가 계속해서 감소하고 있는 것으로 나타났다 전체적인 출생아수 감소의 영향을 피하지 못한 것으로 보이지만 한편으로는 제도적으로 자녀장려라는 본연의 역할을 제대로 조세일보 월 일 구독 빚 만드는 외상결제 서비스업체 연체율 급증에 건전성 우려 물건을 먼저 구입하고 나중에 결제하는 선구매 후불결제 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있
구독 이 맥주 마시지 마세요 식약처 전량 회수조치 왜 식품의약품안전처는 시중에 유통 중인 맥주에 대해 세균수 기준 부적합으로 판매 중단 및 회수조치를 내렸다고 밝혔다 해당 제품은 오비맥주 광주공장에서 제조한 버드와이저 제로 다 조선비즈 월 일 구독 수천억에 사도 할 수 있는 것 없어 동원 손사래 친 맥도날드 자율권 제한 동원그룹 맥도날드 인수 포기 메뉴 하나도 글로벌 본사 허락 필요 년 맥도날드 매각 불발 때도 자율권 걸림돌 지적 업계 스타벅스와 달리 작은 것 하나도 본사 허락받아야 그룹 운영 당시 월간산 월 일 구독 반려견 산행 펫티켓 반려견 산행 위한 첫걸음 그건 안 돼요 원점회귀해야 됩니다 왜요 반려견은 케이지 없이 지하철 못 타요 아 우리의 대화는 대체로  ...

# %% [markdown]
# ### 과제 3
#
# url = 'http://news.naver.com' 에서 문서를 가져와서 p 태그의 한글을 모두 출력하세요.

# %%
url = 'http://news.naver.com'

data = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')
# print(soup)

p = soup.find_all('p')

p = ' '.join([i.get_text() for i in p])
# print(p)

p = ' '.join(re.findall(r'[가-힣]+', p))
print(p)
# Out:
# 이철규 국민의힘 사무총장 대선 경선 치르며 처음 인연 맺었다 당 사무총장 살림하고 책임지는 자리 공천 순위는 주민 위해 봉사할 인물 쓴소리에 귀 닫지 않는 열린 마음 소유자 검사 많다고 국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다 일 업계에 따르면 지난해 제네시스 브랜 한국수력원자력은 지난해 월 폴란드전력공사 와 폴란드 원전 건설과 관련한 협력의향서 을 체결했다 원전사업 규모는 최대 억달러 약 조원 에 달할 것으로 전망된다 그런데 이 사업이 예정대로 증권발 폭락 사태에 대해 전문가들의 사전 경고가 있었지만 사태 예방에는 별다른 효과가 없었던 것으로 나타났다 또한 주가조작 의심 세력이 고른 종목 다수는 증권사들이 기업분석 대상에 포함하지 않아 비정상적 주가 활동 무대 옮겨가며 미성년자 성 착취하는 유사 번방 기승 팸 옵챗 오픈채팅 들어가지마셈 온라인 커뮤니티 디시인사이드의 우울증 갤러리 에는 최근 이 같은 내용의 게시물이 여러 건 최근 무더기 하한가 로 드러난 주가조작 사태는 지난 년 월에 개봉한 영화 작전 을 떠오르게 합니다 결국 주식시장은 년이 지나고도 달라진 게 없었는데요 오히려 차익결제거래 라는 레버리지 상품 정부가 특별법 제정으로 추진하는 전세사기 피해자 지원 및 주거안정 방안 은 야당이 발의한 법안에 비해 지원 대상이 한정됐다 피해자들과 야당이 요구하는 정부의 전세보증금반환채권 매입 방안도 빠졌다 정부가 특별법을 그 어디보다 안전해야 할 스쿨존에서 어린이들이 음주운전 차량에 목숨을 잃는 사고가 끊이지 않고 있습니다 경찰이 이 스쿨존과 행락지에서 오늘 일 음주단속을 한다고 해서 저희 사회부 박재연 기자가 그 현장에 다녀 미국을 국빈 방문한 윤석열 대통령이 참석한 행사에 배우 이서진이 모습을 나타냈다 윤 대통령은 지난 일 현지시간 워싱�
http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId={region_code}'
data = requests.get(url)

soup = BeautifulSoup(data.text, 'html.parser')
# print(soup)

wf = soup.find_all('wf')
wf = ' '.join(wf.get_text() for wf in wf)
wf = ' '.join(re.findall(r'[가-힣]+', wf))

print(wf)
# Out:
# 하늘상태 이번 예보기간은 대체로 흐린 날이 많겠으나 일 월 일 목 은 대체로 맑겠습니다 기온 이번 예보기간 아침 기온은 도로 평년 최저기온 도 과 비슷하거나 조금 높겠고 낮 기온은 도로 평년 최고기온 도 과 비슷하거나 조금 낮겠습니다 해상 동해중부해상의 물결은 일 금 일 토 은 로 높게 일겠습니다 주말전망 일 토 일 일 은 대체로 흐리겠습니다 아침 기온은 도 낮 기온은 도가 되겠습니다 일 목 부터 일 일 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 구름많음 맑음 맑음 구름많음 구름많음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음 구름많음 흐림 흐림 흐림 흐림 흐림 흐림 맑음 맑음 맑음 맑음 맑음 맑음

# %%
region_code = '105'

url = f'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId={region_code}'
data = requests.get(url)

soup = BeautifulSoup(data.text, 'html.parser')
# print(soup)

header_wf = soup.find('header').find('wf').get_text()
header_wf = re.findall(r'[가-힣]+', header_wf)
header_wf = ' '.join(header_wf)
print(header_wf, '\n')

for loc in soup.find_all('location') :
#     print(i, '\n')
    
    city = loc.find('city').get_text()
    city = re.search(r'[가-힣]+', city).group()
#     print(city)
    
    for data in loc.find_all('data') :
        tmef = data.find('tmef').get_text()
#         print(tmef)
        
        wf = data.find('wf').get_text()
        wf = ' '.join(re.findall('[가-힣]+', wf))
        # print(weather)

        print(f'{tmef}에 {city}에서 날씨는 {wf} 입니다.\n')
# Out:
# 하늘상태 이번 예보기간은 대체로 흐린 날이 많겠으나 일 월 일 목 은 대체로 맑겠습니다 기온 이번 예보기간 아침 기온은 도로 평년 최저기온 도 과 비슷하거나 조금 높겠고 낮 기온은 도로 평년 최고기온 도 과 비슷하거나 조금 낮겠습니다 해상 동해중부해상의 물결은 일 금 일 토 은 로 높게 일겠습니다 주말전망 일 토 일 일 은 대체로 흐리겠습니다 아침 기온은 도 낮 기온은 도가 되겠습니다 일 목 부터 일 일 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다
#
# 2023-05-04 00:00에 원주에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 원주에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 원주에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 원주에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 원주에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 원주에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 원주에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 원주에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 철원에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 철원에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 철원에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 철원에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 철원에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 철원에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 철원에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 철원에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 화천에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 화천에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 화천에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 화천에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 화천에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 화천에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 화천에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 화천에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 인제에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 인제에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 인제에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 인제에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 인제에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 인제에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 인제에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 인제에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 양구에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 양구에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 양구에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 양구에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 양구에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 양구에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 양구에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 양구에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 춘천에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 춘천에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 춘천에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 춘천에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 춘천에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 춘천에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 춘천에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 춘천에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 홍천에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 홍천에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 홍천에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 홍천에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 홍천에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 홍천에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 홍천에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 홍천에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 횡성에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 횡성에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 횡성에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 횡성에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 횡성에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 횡성에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 횡성에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 횡성에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 영월에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 영월에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 영월에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 영월에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 영월에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 영월에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 영월에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 영월에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 정선에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 정선에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 정선에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 정선에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 정선에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 정선에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 정선에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 정선에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 평창에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 평창에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 평창에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 평창에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 평창에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 평창에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 평창에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 평창에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 대관령에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 대관령에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 대관령에서 날씨는 구름많음 입니다.
#
# 2023-05-08 00:00에 대관령에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 대관령에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 대관령에서 날씨는 구름많음 입니다.
#
# 2023-05-10 00:00에 대관령에서 날씨는 구름많음 입니다.
#
# 2023-05-11 00:00에 대관령에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 강릉에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 강릉에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 강릉에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 태백에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 태백에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 태백에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 속초에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 속초에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 속초에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 고성에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 고성에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 고성에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 양양에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 양양에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 양양에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 동해에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 동해에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 동해에서 날씨는 맑음 입니다.
#
# 2023-05-04 00:00에 삼척에서 날씨는 구름많음 입니다.
#
# 2023-05-04 12:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-05 00:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-05 12:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-06 00:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-06 12:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-07 00:00에 삼척에서 날씨는 흐림 입니다.
#
# 2023-05-07 12:00에 삼척에서 날씨는 맑음 입니다.
#
# 2023-05-08 00:00에 삼척에서 날씨는 맑음 입니다.
#
# 2023-05-08 12:00에 삼척에서 날씨는 맑음 입니다.
#
# 2023-05-09 00:00에 삼척에서 날씨는 맑음 입니다.
#
# 2023-05-10 00:00에 삼척에서 날씨는 맑음 입니다.
#
# 2023-05-11 00:00에 삼척에서 날씨는 맑음 입니다.

# %% [markdown]
# ### 과제 5
#
# 'http://www.naver.com' 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한후 출력하세요

# %%
url = 'http://www.naver.com'

data = requests.get(url)

soup = BeautifulSoup(data.text, 'html.parser')

span = soup.find_all('span')
span = ''.join(span.get_text() for span in span)
span = ''.join(re.findall(r'[가-힣]+', span))
print(span)
# Out:
# 뉴스스탠드바로가기주제별캐스트바로가기타임스퀘어바로가기쇼핑캐스트바로가기로그인바로가기매일쓰는브라우저보안이걱정된다면안전하고빠른최신브라우저웨일로업데이트하세요매일쓰는브라우저보안이걱정된다면다운로드네이버쥬니어네이버해피빈검색한글입력기자동완성레이어삭제설정이초기화된다면도움말을확인해주세요설정이초기화된다면도움말을확인해주세요도움말도움말자동저장끄기자동저장끄기회로또당첨번호동행복권제공동행복권제공원원바로가기바로가기추가추가추가자세히보기도움말신고도움말신고자동완성끄기자동완성끄기쇼핑쇼핑영등포동가영등포동가리스트형썸네일형설정이전다음닫기닫기이전다음닫기닫기이전다음다음닫기닫기이전다음닫기닫기주제별로분류된다양한글모음개의글이전다음주일전살림허선생살림허선생주일전전원주택라이프전원주택라이프주일전응디응디주일전예진예진개월전주일전치코언니치코언니주일전소이쏘이소이쏘이주일전아잉맘아잉맘이전다음펀딩달성애니먼애니먼펀딩달성네이버웹툰가비지타임네이버웹툰가비지타임기부원기부위스타트위스타트펀딩달성위드마이위드마이펀딩달성분트분트기부원기부천리포수목원천리포수목원주일전르노베르노베주일전림림주일전월간전원속의내집월간전원속의내집주일전찰스퍼니처찰스퍼니처개월전리빙레시피리빙레시피개월전치즈순대치즈순대개월전두와나두와나주일전현대리바트현대리바트주일전러브쏭러브쏭주일전슈슈션션슈슈션션개월전다원다원주일전무더니무더니개월전아늑씨아늑씨주일전전원주택라이프전원주택라이프주일전주일전지아롬지아롬주일전얀듀리얀듀리개월전유난유난주일전랑캐랑캐주일전어나더제이어나더제이이전다음언론사헤드라인보기코로나바이러스감염증현황라이트모드로보기

# %% [markdown]
# ### 과제 6
#
# 만든 과제 웹에 DOM 계층 구조를 3단계로 추가하여 작성하세요
