# %%
# 파일에 들어있는 단어수를 계산하여 출력

with open('m.txt', 'r') as f :
    d = f.read()
    tmp = d.split()
    print('단어수: %d' %len(tmp))

# %%
# 파일을 읽고 파일의 내용에서 나타나는 문자들에 대해 자주 나타나는 문자를 출력
#[] ->[]회 나타남

def datacnt(txt) :
    
    with open(txt,'r') as f :
        d = f.read()
        tmp = d.split()
        s = set(d.split())
        x = {}
        
        for i in d :
                
            if i == x :
                x[i] +=1                
            
            else :
                x[i] = 1
    return x

r = datacnt('m.txt')
r = sorted(r.items(), key = lambda x : x[1], reverse = True)

print(r)

for i, freq in r :
    if i == '\n' :
        continue
    print('[%c] - > [%d]회 나타남' %(i,freq))

# %%
# txt 파일에서 특정 단어 t1(a)를 다른 단어 t2(A)로 변경하여 출력하세요

with open('mydata.txt', 'r') as f :
    with open('mydata1.txt', 'w') as h :
        text = f.read()
        text = text.replace('a', 'A')
        h.write(text)
print('%s를 %s로 변경했습니다.' %('a', 'A'))

def datacnt(txt) :
    
    with open(txt,'r') as f :
        d = f.read()
        tmp = d.split()
        s = set(d.split())
        x = {}
        
        for i in d :
                
            if i == x :
                x[i] +=1                
            
            else :
                x[i] = 1
    return x

r = datacnt('mydata1.txt')
r = sorted(r.items(), key = lambda x : x[1], reverse = True)

print(r)

for i, freq in r :
    if i == '\n' :
        continue
    print('[%c] - > [%d]회 나타남' %(i,freq))

# %%
with open('modex.py', 'w') as f :
    f.write(
'''
def add(a, b) :
    return a+b
''')

# %%
with open('modex.py', 'r') as f :
    d = f.read()
    print(d)

# %%
import modex
modex.add(1,1)

# %%
with open('modex1.py', 'w') as f :
    f.write(
'''
def add(a, b) :
    return a + b
print(add(1,1))
''')

# %%
import modex1.py

# %%
# !python add modex1.py

# %% [markdown]
# 파이썬 if __name__ == "__main__" 의미
#
# - 메인 함수의 선언, 시작을 의미합니다. 해당 코드 밑에 main 등의 함수 호출 코드를 작성해서 함수의 기능을 수행
# - 직접 mod.py 파일을 실행하는 경우에는 __name___ 변수에 __main__ 이라는 값이 할당되고 이 조건절이 참이 되어 if문 다음 문장들이 수행
# - 모듈을 불러와서 사용하는 경우 __name__ 변수에는 모듈 이름이 저장되고 이 조건절이 거짓이 되어 if문 다음 문장들이 수행되지 않음
# - if __name__ == "__main__"와 같이 조건문을 사용하여 터미널에서와 같이 직접 호출되어 사용될 때는 그 자체로 기능을 수행하고, 동시에 다른 모듈에서 필요한 함수 등을 제공

# %%
with open('modex2.py', 'w') as f :
    f.write(
'''
def add(a, b) :
    return a + b
if __name__ == "__main__" :
    print(add(1,1))
''')

# %%
# !python modex2.py

# %%
import modex2

# %%
# 사칙연산 기능을 포함하는 모듈을 작성후 임포트 해서 사칙연산을 수행하세요. calt4

with open('calt4.py', 'w') as f :
    f.write(
'''
def cal(a, b) :
    return a + b
if __name__ == "__main__" :
    print(cal(a,b))
''')

# %%
# !python calt4.py

# %%
with open('sys1.py', 'w') as f :
    f.write(
'''
import sys
args = sys.argv[1:]
for i in args :
    print(i)
''')

# %%
# !python sys1.py aaa bbb ccc

# %% [markdown]
# #### 쓰레드 (Thread)
#
# 파이썬 프로그램은 기본적으로 하나의 쓰레드(Single Thread)에서 실행된다. 즉, 하나의 메인 쓰레드가 파이썬 코드를 순차적으로 실행한다. 코드를 병렬로 실행하기 위해서는 별도의 쓰레드(Subthread)를 생성해야 하는데, 파이썬에서 쓰레드를 생성하기 위해서는 threading 모듈 (High 레벨) 혹은 thread 모듈 (Low 레벨)을 사용할 수 있다. 일반적으로 쓰레드 처리를 위해서는 thread 모듈 위에서 구현된 threading 모듈을 사용하고 있으며, thread 모듈은 (deprecate 되어) 거의 사용하고 있지 않다.

# %%
import time

def long_task() :
    for i in range(5) :
        time.sleep(0.5)
        print('work : %s\n' % i)

print('start')

for i in range(5) :
    long_task()
    
print('end')

# %%
# 파이썬에서 쓰레드를 실행하기 위해서는, threading 모듈의 threading.Thread() 함수를 호출하여 
# Thread 객체를 얻은 후 Thread 객체의 start() 메서드를 호출
# 쓰레드가 실행할 함수 (혹은 메서드)를 작성하고 그 함수명을 threading.Thread() 함수의 target 아큐먼트에 지정
# 프로그램을 수정하고 실행해 보면 25초 걸리던 작업이 5초 정도에 수행되는 것을 확인할 수 있다. 
# threading.Thread를 사용하여 만든 스레드 객체가 동시 작업을 가능하게 해 주기 때문임

import time
import threading



def long() :
    for i in range(5) :
        time.sleep(1)
        print('work : %s\n' % i)

        
print('start')
        
threads = []    

for i in range(5) :
    t = threading.Thread(target = long)
    threads.append(t)

for t in threads :
    t.start()
    
for t in threads :
    t.join() # join 으로 스레드가 종료 될 때까지 기다린다.
    
print('END')

# %% [markdown]
# #### 파이썬에서 언더바/언더스코어(_) 의 의미와 역할
#
# 일단 6개의 다른 용도
# - 인터프리터에서의 사용
# - 무시하는 값
# - 루프에서 사용
# - 숫자값의 분리
# - 명명용
#     - 앞에 하나가 쓰이는 경우
#     - 뒤에 하나가 쓰이는 경우
#     - 앞에 두개가 쓰이는 경우
#     - 앞 뒤로 두개씩 쓰이는 경우
#
# https://eine.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%97%90%EC%84%9C-%EC%96%B8%EB%8D%94%EB%B0%94%EC%96%B8%EB%8D%94%EC%8A%A4%EC%BD%94%EC%96%B4-%EC%9D%98-%EC%9D%98%EB%AF%B8%EC%99%80-%EC%97%AD%ED%95%A0

# %%
# 파이썬 인터 프리터에 가장 마지막 표현식의 결과값을 자동적으로 _라는 변수에 저장

5 + 4

# %%
_

# %%
a, _, b = (1,2,3) # a = 1 _무시 b = 3

print(a,b)

a, *_, b = (7,6,5,4,3,2,1)
print(a, b)

# %%
for _ in range(5) :
    print(_)

# %%
lan = ['a', 'b', 'c']

for _ in lan :
    print(_)

# %%
_= 5
while _ < 10 :
    print(_, end = ' ')
    _ += 1

# %%
# 숫자가 길다면 자릿수 구분을 위해 사용

M = 1_000_000
bina = 0b_0010
octa = 0o_64
hexa = 0x_23_ab

print(M)
print(bina)
print(octa)
print(hexa)

# %%
# __init__ 생성자 호출없이 초기화할때 호출되는 함수
# 앞의 하나의 _로 시작하는 이름은 내부 사용용

class Test :
    def __init__(self) :
        self.name = 'datacamp'
        self._num = 7
obj = Test()
print(obj.name)
print(obj._num)

# %%
# 마지막 부분에 언더바를 하나 추가하면 파이썬의 기본 키워드와 충돌 방지

def function(class) :
    pass

# %%
def function(class_) :
    pass

# %%
# titanic 데이터셋에서 age 컬럼을 아래와 같이 범주화 하세요.
# Baby child Tennager Young Adult Elderly

# %%
import seaborn as sns

tt = sns.load_dataset('titanic')
tt.head() # 앞 5줄을 출력

# %%
# 나이 별 분포

tt.age.plot(kind = 'hist')

# %%
# 범주화

def age_cat(age) :
    cat = ''
    if age <= 5 : cat = 'Baby'
    elif age <= 12 : cat = 'Child'
    elif age <= 18  : cat = 'Teenager'
    elif age <= 35 : cat = 'Young Adult'
    elif age <= 60 : cat = 'Adult'
    else : 'elderly'
    return cat

tt['age_cat'] = tt['age'].apply(lambda x : age_cat(x))
tt.head()

# %%
tt.age.unique()

# %%
# !pip install Pillow

# %%
from PIL import Image
im = Image.open('imgname.jpg')
im.show()

# %%
# 123456789를 입력하면 천 단위로 콤마로 구분하여 출력

x = int(input('숫자를 입력하세요. : '))

print('{:,}'.format(x))
print(format(x,','))

# %%
num = input('숫자를 입력해주세요. :')

if num.isdigit() :
    num = num[::-1]
    ret = ''
    
    for i, c in enumerate(num) :
        i += 1
        if i != len(num) and i % 3 == 0 :
            ret += (c+',')
        else :
            ret += c
    ret = ret[::-1]
    print(ret)
else:
    print(f'입력한 내용 {num} : 숫자가 아닙니다.')
# Out:
# 숫자를 입력해주세요. :123456789
# 123,456,789

# %%
# example_list = ['요소A', '요소B', '요소C']를 파이썬 내장 함수를 이용하여 아래와 같이 출력
# 0번째 요소는 요소A입니다.
# 1번째 요소는 요소B입니다.
# 2번째 요소는 요소C입니다.

example_list = ['요소A', '요소B', '요소C']

for i in range(len(example_list)) :
    
    x = example_list[i]
    
    print('%d번째 요소는 %s입니다.' %(i,x))
#    print(f'{i}번째 요소는 {x}입니다.')
# Out:
# 0번째 요소는 요소A입니다.
# 1번째 요소는 요소B입니다.
# 2번째 요소는 요소C입니다.

# %%
example_list = ['요소A', '요소B', '요소C']

for i, j in enumerate(example_list) :
    print(f'{i}번째 요소는 {j}입니다.')
# Out:
# 0번째 요소는 요소A입니다.
# 1번째 요소는 요소B입니다.
# 2번째 요소는 요소C입니다.

# %%
# 500 1000사이의 정수중 5와 7 공배수의 합 구하기

r = 0

for i in range(500, 1001) :
    
    if (i % 5 == 0) & (i % 7 == 0) :
        
        r += i
           
print(r)
# Out:
# 10535

# %%
def mul_a(x, y) :
    
    r = 0
    
    for i in range(x, y) :
        
        if  (i % 2 == 0) & (i % 5 == 0) :
            r += i
            
        else :
            i += 1
    
    return r


print(mul_a(1, 101))

# %%
with open('yob1880.txt', 'r') as f :
    data = f.read()
    
    print(data)

# %%
import re

with open('yob1880.txt', 'r') as f :

    data = f.readlines()
    
    r = 0
    
    for i in data :
        
        num = re.findall('\d+', i)
        num = ''.join(num) # 리스트를 문자로
        r += int(num) # 문자를 숫자로

        
    print(f'1880년에 태어난 출생아 수 {r}명')
# Out:
# 1880년에 태어난 출생아 수 201482명

# %%
# 주어진 데이터에서 1880년에서 2015년 까지 연도별 출생아 수
import re

def bcnt(a, b) :
    

    for i in range(a, b + 1) :

        t = (f'yob{i}.txt')


        with open(t, 'r') as f :

            data = f.readlines()
            

            r = 0

            for n in data :

                num = re.findall('\d+', n) # \d+ 하나 혹은 그 이상 연결된 숫자
                num = ''.join(num) # 리스트를 문자로
                r += int(num) # 문자를 숫자로

            r1 = print(f'{i}년에 태어난 출생아 수 {r}명\n')
            
    return r1

bcnt(1880,2015)
# Out:
# 1880년에 태어난 출생아 수 201482명
#
# 1881년에 태어난 출생아 수 192696명
#
# 1882년에 태어난 출생아 수 221534명
#
# 1883년에 태어난 출생아 수 216945명
#
# 1884년에 태어난 출생아 수 243463명
#
# 1885년에 태어난 출생아 수 240854명
#
# 1886년에 태어난 출생아 수 255319명
#
# 1887년에 태어난 출생아 수 247396명
#
# 1888년에 태어난 출생아 수 299474명
#
# 1889년에 태어난 출생아 수 288948명
#
# 1890년에 태어난 출생아 수 301401명
#
# 1891년에 태어난 출생아 수 286675명
#
# 1892년에 태어난 출생아 수 334377명
#
# 1893년에 태어난 출생아 수 325222명
#
# 1894년에 태어난 출생아 수 338692명
#
# 1895년에 태어난 출생아 수 351024명
#
# 1896년에 태어난 출생아 수 357486명
#
# 1897년에 태어난 출생아 수 346958명
#
# 1898년에 태어난 출생아 수 381461명
#
# 1899년에 태어난 출생아 수 339235명
#
# 1900년에 태어난 출생아 수 450312명
#
# 1901년에 태어난 출생아 수 345816명
#
# 1902년에 태어난 출생아 수 386734명
#
# 1903년에 태어난 출생아 수 381205명
#
# 1904년에 태어난 출생아 수 403496명
#
# 1905년에 태어난 출생아 수 423941명
#
# 1906년에 태어난 출생아 수 428461명
#
# 1907년에 태어난 출생아 수 465395명
#
# 1908년에 태어난 출생아 수 488658명
#
# 1909년에 태어난 출생아 수 511231명
#
# 1910년에 태어난 출생아 수 590719명
#
# 1911년에 태어난 출생아 수 644271명
#
# 1912년에 태어난 출생아 수 988059명
#
# 1913년에 태어난 출생아 수 1137094명
#
# ...

# %%
# 연도 성별 출생아수 구하기
# https://pybasall.tistory.com/214
# Q print를 썼을때 none이 나오는 이유

import re # 정규 표현식

def birth(a, b) :
    
    for i in range(a, b + 1) :
        
        y = (f'yob{i}.txt')
        
        with open(y, 'r') as f :
            
            data = f.readlines()
            
            r = 0
            r1 = 0
            
            for j in data :

                gender = re.findall(',\w,', j)
                gender = ''.join(gender)
                gender = gender.replace(',', '')
                    
                num = re.findall('\d+', j)
                num = ''.join(num)
                
                if gender == 'M' :
                    
                    r += int(num)
                    
                
                else :
                    
                    r1 += int(num)
                    
            r2 = print(f'{i}년에 태어난 성별이 M 인 출생아 수 {r}명 성별이 F 인 출생아 수 {r1}명\n')
        
  
    return r2


birth(1880,2015)
# Out:
# 1880년에 태어난 성별이 M 인 출생아 수 110490명 성별이 F 인 출생아 수 90992명
#
# 1881년에 태어난 성별이 M 인 출생아 수 100743명 성별이 F 인 출생아 수 91953명
#
# 1882년에 태어난 성별이 M 인 출생아 수 113686명 성별이 F 인 출생아 수 107848명
#
# 1883년에 태어난 성별이 M 인 출생아 수 104627명 성별이 F 인 출생아 수 112318명
#
# 1884년에 태어난 성별이 M 인 출생아 수 114443명 성별이 F 인 출생아 수 129020명
#
# 1885년에 태어난 성별이 M 인 출생아 수 107799명 성별이 F 인 출생아 수 133055명
#
# 1886년에 태어난 성별이 M 인 출생아 수 110785명 성별이 F 인 출생아 수 144534명
#
# 1887년에 태어난 성별이 M 인 출생아 수 101415명 성별이 F 인 출생아 수 145981명
#
# 1888년에 태어난 성별이 M 인 출생아 수 120850명 성별이 F 인 출생아 수 178624명
#
# 1889년에 태어난 성별이 M 인 출생아 수 110582명 성별이 F 인 출생아 수 178366명
#
# 1890년에 태어난 성별이 M 인 출생아 수 111025명 성별이 F 인 출생아 수 190376명
#
# 1891년에 태어난 성별이 M 인 출생아 수 101193명 성별이 F 인 출생아 수 185482명
#
# 1892년에 태어난 성별이 M 인 출생아 수 122036명 성별이 F 인 출생아 수 212341명
#
# 1893년에 태어난 성별이 M 인 출생아 수 112317명 성별이 F 인 출생아 수 212905명
#
# 1894년에 태어난 성별이 M 인 출생아 수 115770명 성별이 F 인 출생아 수 222922명
#
# 1895년에 태어난 성별이 M 인 출생아 수 117396명 성별이 F 인 출생아 수 233628명
#
# 1896년에 태어난 성별이 M 인 출생아 수 119568명 성별이 F 인 출생아 수 237918명
# ...

# %% [markdown]
# 과제 - Q54.
# 카운터에서 거스름돈으로 사용할 500원, 100원, 50원, 10원짜리 동전이 무한히 존재한다고 가정한다.
# 손님에게 거슬러 줘야 할 돈이 N원일 때 거슬러줘야 할 동전의 최소 개수를 구하세요.
# 거슬러 줘야 할 돈 N은 항상 10의 배수이다. N은 2750원이다.

# %%
cnt = 0
coins = [500, 100, 50, 10]


while True :
    
    try :

        m_c = int(input('거슬러 주어야 할 금액 : ')) 
        print('')

    except :

        print('\n잘못 입력하셨습니다. 올바른 금액을 다시 입력해주세요.\n')
        continue

    else :

        if m_c > 0 :

            for i in coins :

                cnt += m_c // i

                m_c = m_c % i
                
            print(f'거슬러 주어야 할 금액에 대한 동전의 최소 개수는 {cnt} 개 입니다.')
                

        else :
            print('\n잘못 입력하셨습니다. 올바른 금액을 다시 입력해주세요.\n')
            continue
    
    break
# Out:
# 거슬러 주어야 할 금액 : 10
#
# 거슬러 주어야 할 금액에 대한 동전의 최소 개수는 1 개 입니다.

# %% [markdown]
# 과제 - Q56.
# 파일이름과 특정 단어을 인자로 입력하면 그 파일에 있는 특정 단어의 개수를 반환하는
# 사용자 함수를 이용하여 mydata 파일에서 how의 개수를 출력하세요.

# %%
def find_d(name, word) :
    
    with open(name, 'r') as f :
        
        data = f.read()
        
        r = data.count(word)
        
        return r

find_d('mydata.txt', 'how')
# Out:
# 2

# %%
def countword(file, word) :
    with open(file, 'r') as f :
        txt = f.read()
        txt = txt.lower()
        pos = txt.find(word)# 인덱스
        count = 0
        while pos != -1 :  # 존재할때
            count += 1
            pos = txt.find(word, pos + 1)
    return count

file = input('file 이름을 입력해주세요. : ')
word = input('file 에서 개수를 구할 단어를 입력하세요. :')
ret = countword(file, word)
print(f'{word}의 개수: {ret}')
# Out:
# file 이름을 입력해주세요. : mydata.txt
# file 에서 개수를 구할 단어를 입력하세요. :how
# how의 개수: 2

# %% [markdown]
# #### 파이썬에서 -1은 다양한 방식으로 사용됩니다. 다음은 일부 예시입니다:
#
# - 인덱스: 파이썬에서는 리스트, 문자열, 튜플 등의 시퀀스 자료형의 인덱스를 지정할 때 음수를 사용할 수 있습니다. 이때 -1은 시퀀스의 마지막 요소를 가리킵니다. 예를 들어, 리스트에서 my_list[-1]은 리스트의 마지막 요소를 반환합니다.
#
# - 슬라이스: 마찬가지로, 시퀀스 자료형의 슬라이스를 지정할 때도 음수를 사용할 수 있습니다. 이때 -1은 시퀀스의 마지막 요소를 가리킵니다. 예를 들어, 리스트에서 my_list[:-1]은 마지막 요소를 제외한 모든 요소를 반환합니다.
#
# - 반환 값: 일부 함수에서는 실패 또는 오류를 나타내는 값을 -1로 반환합니다. 예를 들어, 문자열에서 find() 메서드는 문자열에서 지정된 문자열을 찾을 수 없을 때 -1을 반환합니다.
#
# - 비트 연산: 비트 연산에서는 -1이 모든 비트가 1인 이진수로 사용됩니다. 예를 들어, 0b11111111은 10진수로 255이며, -1과 같습니다.
